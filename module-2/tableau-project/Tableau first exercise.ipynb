# %%
import pandas as pd

# %%
data=pd.read_csv('./tableau_project.csv')
data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 1           1  444b084ec64244919afadfba879876a3
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 3           3  1ffe9a24033847148c683574985df56c
# 4           4  fb1ef7d070724482a33be41f27737ea5
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 1  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:06:16
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 3  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 09:17:08
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
#
#    start_lat  start_lon               end_at    end_lat    end_lon  ...  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260  ...
# 1  19.431567 -99.195368  2017-12-16 11:07:21        NaN        NaN  ...
# ...

# %%
columns=list(data.columns)
tp=data['start_type'].value_counts()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3864 entries, 0 to 3863
# Data columns (total 22 columns):
# Unnamed: 0             3864 non-null int64
# journey_id             3864 non-null object
# vehicle_type_id        3864 non-null object
# start_type             3864 non-null object
# start_at               3864 non-null object
# start_lat              3864 non-null float64
# start_lon              3864 non-null float64
# end_at                 3864 non-null object
# end_lat                3807 non-null float64
# end_lon                3807 non-null float64
# end_state              3864 non-null object
# price                  3844 non-null object
# price_distance         2812 non-null object
# price_duration         2812 non-null object
# distance               3844 non-null object
# duration               3844 non-null object
# source                 3864 non-null object
# rider_waiting_time     2733 non-null object
# driver_waiting_time    2685 non-null object
# ...

# %%
data1=data[['price','start_lat','start_lon','end_lat','end_lon','end_state','distance','duration','rating','rider_waiting_time','vehicle_type_id']]

# %%
data1.dropna()
# Out:
#        price  start_lat  start_lon    end_lat    end_lon     end_state  \
# 0      5,866  19.431363 -99.195362  19.406438 -99.175260      drop off
# 2      4,000  19.422052 -99.174499  19.438666 -99.180821      drop off
# 4      4,000  19.440996 -99.183581  19.422815 -99.174865      drop off
# 5      4,000  19.421856 -99.174361  19.440311 -99.184146      drop off
# 7      6,449  19.419962 -99.171955  19.441434 -99.183503      drop off
# 9      8,063  19.438666 -99.180821  19.423103 -99.174878      drop off
# 11     6,924  19.421541 -99.174171  19.442719 -99.201140      drop off
# 12     4,000  19.422815 -99.174865  19.406438 -99.175260      drop off
# 15     9,404  19.441434 -99.183503  19.439331 -99.202260      drop off
# 17     5,299  19.406353 -99.175294  19.432267 -99.154651      drop off
# 18     4,000  19.422815 -99.174865  19.406438 -99.175260      drop off
# 21     4,000  19.440754 -99.183578  19.422815 -99.174865      drop off
# ...

# %%
data1.head()
# Out:
#    price  start_lat  start_lon    end_lat    end_lon     end_state distance  \
# 0  5,866  19.431363 -99.195362  19.406438 -99.175260      drop off    7,943
# 1      0  19.431567 -99.195368        NaN        NaN  rider cancel        0
# 2  4,000  19.422052 -99.174499  19.438666 -99.180821      drop off    3,054
# 3      0  19.433119 -99.154844  19.290148 -99.144407  rider cancel        0
# 4  4,000  19.440996 -99.183581  19.422815 -99.174865      drop off    2,859
#
#   duration  rating rider_waiting_time                   vehicle_type_id
# 0    1,058     9.0                590  077866c3fd1a75f51ca7f8eae166ae32
# 1        0     9.0                NaN  077866c3fd1a75f51ca7f8eae166ae32
# 2      689    10.0                923  077866c3fd1a75f51ca7f8eae166ae32
# 3        0     9.0                NaN  077866c3fd1a75f51ca7f8eae166ae32
# 4      887     8.0                329  077866c3fd1a75f51ca7f8eae166ae32

# %%
data1['rating'].value_counts()
# Out:
# 9.0     1390
# 8.0      930
# 10.0     616
# 6.0      572
# 7.0      355
# 4.0        1
# Name: rating, dtype: int64

# %%
data1 = data1.drop(data1[data1['rating']==4].index)

# %%
data1['rating'].value_counts()
# Out:
# 9.0     1390
# 8.0      930
# 10.0     616
# 6.0      572
# 7.0      355
# Name: rating, dtype: int64

# %%
data1.to_csv('./taxis.csv', sep='\t')
