# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./tableau_project.csv')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 1           1  444b084ec64244919afadfba879876a3
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 3           3  1ffe9a24033847148c683574985df56c
# 4           4  fb1ef7d070724482a33be41f27737ea5
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 1  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:06:16
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 3  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 09:17:08
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
#
#    start_lat  start_lon               end_at    end_lat    end_lon  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260
# 1  19.431567 -99.195368  2017-12-16 11:07:21        NaN        NaN
# ...

# %%
data1 = data.drop(['Unnamed: 0', 'journey_id','vehicle_type_id','start_type'], axis=1)
data1.head(50)
# Out:
#                start_at  start_lat  start_lon               end_at    end_lat  \
# 0   2017-12-16 11:08:59  19.431363 -99.195362  2017-12-16 11:37:32  19.406438
# 1   2017-12-16 11:06:16  19.431567 -99.195368  2017-12-16 11:07:21        NaN
# 2   2017-11-24 22:58:37  19.422052 -99.174499  2017-11-24 23:27:05  19.438666
# 3   2017-12-16 09:17:08  19.433119 -99.154844  2017-12-16 09:17:30  19.290148
# 4   2017-11-24 18:11:00  19.440996 -99.183581  2017-11-24 18:31:31  19.422815
# 5   2017-11-24 15:34:53  19.421856 -99.174361  2017-11-24 15:53:30  19.440311
# 6   2017-11-24 15:10:23  19.419962 -99.171955  2017-11-24 15:10:42  19.441434
# 7   2017-11-24 15:09:29  19.419962 -99.171955  2017-11-24 15:47:42  19.441434
# 8   2017-11-24 14:31:58  19.406538 -99.169710  2017-11-24 14:32:56  19.421960
# 9   2017-11-24 14:20:00  19.438666 -99.180821  2017-11-24 14:36:44  19.423103
# 10  2017-11-30 23:03:44  19.421545 -99.174222  2017-11-30 23:03:50  19.442719
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3864 entries, 0 to 3863
# Data columns (total 18 columns):
# start_at               3864 non-null object
# start_lat              3864 non-null float64
# start_lon              3864 non-null float64
# end_at                 3864 non-null object
# end_lat                3807 non-null float64
# end_lon                3807 non-null float64
# end_state              3864 non-null object
# price                  3844 non-null object
# price_distance         2812 non-null object
# price_duration         2812 non-null object
# distance               3844 non-null object
# duration               3844 non-null object
# source                 3864 non-null object
# rider_waiting_time     2733 non-null object
# driver_waiting_time    2685 non-null object
# price_supplements      3864 non-null object
# discount               3844 non-null object
# rating                 3864 non-null float64
# dtypes: float64(5), object(13)
# ...

# %%
before = len(data1)
data2 = data1.drop_duplicates()
after = len(data2)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
data2.isnull().sum()
# Out:
# start_at                  0
# start_lat                 0
# start_lon                 0
# end_at                    0
# end_lat                  57
# end_lon                  57
# end_state                 0
# price                    20
# price_distance         1052
# price_duration         1052
# distance                 20
# duration                 20
# source                    0
# rider_waiting_time     1131
# driver_waiting_time    1179
# price_supplements         0
# discount                 20
# rating                    0
# dtype: int64

# %%
#price_distance y price_duration se relacionan con rider cancel en end_state. Pasarlo a cero
#rider_waiting_time y driver_waiting_time quiere decir que el tiempo fue cero, pero xq el viaje se canceló. Pasarlo a cero

# %%
data2['end_state'].value_counts()
# Out:
# drop off         2685
# rider cancel     1146
# not found          20
# no show            12
# driver cancel       1
# Name: end_state, dtype: int64
