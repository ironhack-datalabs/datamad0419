# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('tableau_project (1).csv')

# %%
data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 1           1  444b084ec64244919afadfba879876a3
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 3           3  1ffe9a24033847148c683574985df56c
# 4           4  fb1ef7d070724482a33be41f27737ea5
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 1  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:06:16
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 3  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 09:17:08
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
#
#    start_lat  start_lon               end_at    end_lat    end_lon  ...  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260  ...
# 1  19.431567 -99.195368  2017-12-16 11:07:21        NaN        NaN  ...
# ...

# %%
display(data)
# Out:
#       Unnamed: 0                        journey_id  \
# 0              0  93e6d216088af74c32183283d4bb2953
# 1              1  444b084ec64244919afadfba879876a3
# 2              2  dbcc57f4e7606a71c74c6e4666a977a4
# 3              3  1ffe9a24033847148c683574985df56c
# 4              4  fb1ef7d070724482a33be41f27737ea5
# 5              5  310f2f7103dd41c9811bffa771776648
# 6              6  0a5bb1448fa2418581b7171df9f6d1a4
# 7              7  643a2da9e5f9457ab4a1706875c92d10
# 8              8  38aa6d5e20294992a6c31827d3a5a5c7
# 9              9  bd801b036699c6fdfdc530a6334ae88f
# 10            10  d61f40bbe1f942a8b9acab3a3f3d74f3
# 11            11  3fbde2354fd74135a87ce20b14af9a25
# 12            12  616bacc8c3d59829127c22f8eeb2ad34
# 13            13  0cdf9c4e11e5ed944879473e036ddc02
# 14            14  e0cd89ab902bcc6e6ba14de7606ee2d8
# 15            15  6dc46eede5d54730bdb0a9919ec0a2f1
# 16            16  65fa0803b8da46e8afc7a88909b3eaca
# ...

# %%
null_cols = data.isnull().sum()
null_cols[null_cols > 0]
# Out:
# end_lat                  57
# end_lon                  57
# price                    20
# price_distance         1052
# price_duration         1052
# distance                 20
# duration                 20
# rider_waiting_time     1131
# driver_waiting_time    1179
# discount                 20
# dtype: int64

# %%
before = len(data)
data = data.drop_duplicates()
after = len(data)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
data[['end_state','price']]
# Out:
#          end_state   price
# 0         drop off   5,866
# 1     rider cancel       0
# 2         drop off   4,000
# 3     rider cancel       0
# 4         drop off   4,000
# 5         drop off   4,000
# 6     rider cancel       0
# 7         drop off   6,449
# 8     rider cancel       0
# 9         drop off   8,063
# 10    rider cancel       0
# 11        drop off   6,924
# 12        drop off   4,000
# 13    rider cancel       0
# 14    rider cancel       0
# 15        drop off   9,404
# 16    rider cancel       0
# 17        drop off   5,299
# 18        drop off   4,000
# 19    rider cancel       0
# 20    rider cancel       0
# 21        drop off   4,000
# 22        drop off   4,000
# 23        drop off   4,000
# 24        drop off   6,582
# 25    rider cancel       0
# 26        drop off   4,000
# 27        drop off   5,438
# 28    rider cancel       0
# 29    rider cancel       0
# ...            ...     ...
# 3834  rider cancel       0
# 3835      drop off   4,000
# ...

# %%
data[['end_state','source']]
# Out:
#          end_state   source
# 0         drop off  Android
# 1     rider cancel   iPhone
# 2         drop off  Android
# 3     rider cancel   iPhone
# 4         drop off   iPhone
# 5         drop off   iPhone
# 6     rider cancel   iPhone
# 7         drop off   iPhone
# 8     rider cancel   iPhone
# 9         drop off  Android
# 10    rider cancel   iPhone
# 11        drop off   iPhone
# 12        drop off  Android
# 13    rider cancel  Android
# 14    rider cancel  Android
# 15        drop off   iPhone
# 16    rider cancel   iPhone
# 17        drop off   iPhone
# 18        drop off  Android
# 19    rider cancel  Android
# 20    rider cancel   iPhone
# 21        drop off   iPhone
# 22        drop off   iPhone
# 23        drop off   iPhone
# 24        drop off  Android
# 25    rider cancel  Android
# 26        drop off   iPhone
# 27        drop off   iPhone
# 28    rider cancel   iPhone
# 29    rider cancel   iPhone
# ...            ...      ...
# 3834  rider cancel   iPhone
# ...

# %%
list(data)
# Out:
# ['Unnamed: 0',
#  'journey_id',
#  'vehicle_type_id',
#  'start_type',
#  'start_at',
#  'start_lat',
#  'start_lon',
#  'end_at',
#  'end_lat',
#  'end_lon',
#  'end_state',
#  'price',
#  'price_distance',
#  'price_duration',
#  'distance',
#  'duration',
#  'source',
#  'rider_waiting_time',
#  'driver_waiting_time',
#  'price_supplements',
#  'discount',
#  'rating']

# %%
#select_columns = ['Unnamed: 0',
 #'discount',
 #'distance'
 #]

#data = data[select_columns].drop_duplicates()
#after = len(data)
#print('Number of duplicate records dropped: ', str(before - after))

# %%
data.drop(['journey_id', 'driver_waiting_time','price_supplements','discount','price_duration','start_type','Unnamed: 0'], axis='columns', inplace=True)

# %%
data.head()
# Out:
#                     vehicle_type_id             start_at  start_lat  \
# 0  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:08:59  19.431363
# 1  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:06:16  19.431567
# 2  077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 22:58:37  19.422052
# 3  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 09:17:08  19.433119
# 4  077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 18:11:00  19.440996
#
#    start_lon               end_at    end_lat    end_lon     end_state  price  \
# 0 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260      drop off  5,866
# 1 -99.195368  2017-12-16 11:07:21        NaN        NaN  rider cancel      0
# 2 -99.174499  2017-11-24 23:27:05  19.438666 -99.180821      drop off  4,000
# 3 -99.154844  2017-12-16 09:17:30  19.290148 -99.144407  rider cancel      0
# 4 -99.183581  2017-11-24 18:31:31  19.422815 -99.174865      drop off  4,000
#
#   price_distance distance duration   source rider_waiting_time  rating
# ...

# %%
 data.fillna(0)
# Out:
#                        vehicle_type_id             start_at  start_lat  \
# 0     077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:08:59  19.431363
# 1     077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:06:16  19.431567
# 2     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 22:58:37  19.422052
# 3     077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 09:17:08  19.433119
# 4     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 18:11:00  19.440996
# 5     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 15:34:53  19.421856
# 6     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 15:10:23  19.419962
# 7     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 15:09:29  19.419962
# 8     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 14:31:58  19.406538
# 9     077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 14:20:00  19.438666
# 10    077866c3fd1a75f51ca7f8eae166ae32  2017-11-30 23:03:44  19.421545
# 11    077866c3fd1a75f51ca7f8eae166ae32  2017-11-30 23:02:14  19.421541
# ...

# %%
data['start_lat'] = data['start_lat'].astype(str)
data['start_lon'] = data['start_lon'].astype(str)
data['end_lat'] = data['end_lat'].astype(str)
data['end_lon'] = data['end_lon'].astype(str)

# %%
data.head()
# Out:
#                     vehicle_type_id             start_at           start_lat  \
# 0  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:08:59          19.4313629
# 1  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 11:06:16  19.431566759000003
# 2  077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 22:58:37       19.4220518545
# 3  077866c3fd1a75f51ca7f8eae166ae32  2017-12-16 09:17:08       19.4331187103
# 4  077866c3fd1a75f51ca7f8eae166ae32  2017-11-24 18:11:00  19.440996018499998
#
#             start_lon               end_at     end_lat      end_lon  \
# 0          -99.195362  2017-12-16 11:37:32  19.4064378  -99.1752599
# 1  -99.19536788030001  2017-12-16 11:07:21         nan          nan
# 2  -99.17449861760001  2017-11-24 23:27:05   19.438666  -99.1808212
# 3  -99.15484447969999  2017-12-16 09:17:30  19.2901477  -99.1444066
# 4  -99.18358124790001  2017-11-24 18:31:31  19.4228147  -99.1748655
#
#       end_state  price price_distance distance duration   source  \
# ...

# %%
new_data=data
new_data.to_csv('tableaucoches.csv')
