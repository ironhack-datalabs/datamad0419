# %%
# Importo las librerías que voy a usar

import pymongo
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

from pandas.io.json import json_normalize

import pandas as pd

# %%
# Obtengo todo el dataset para visualizarlo bien

data = db.companies.find()
dataset = pd.DataFrame(list(data))
pd.set_option("display.max_columns", 500)
display(dataset.head())
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8c
# 2  52cdef7c4bab8bd675297d8a
# 3  52cdef7c4bab8bd675297d8f
# 4  52cdef7c4bab8bd675297d90
#
#                                          acquisition acquisitions  \
# 0                                               None           []
# 1                                               None           []
# 2  {'price_amount': 30000000, 'price_currency_cod...           []
# 3                                               None           []
# 4  {'price_amount': 625000000, 'price_currency_co...           []
#
#            alias_list                          blog_feed_url  \
# 0  Zoho ManageEngine
# 1                                 http://blogs.zoho.com/feed
# 2                           http://digitalquarters.net/feed/
# 3                None  http://feeds.feedburner.com/omnidrive
# 4                None
#
#                         blog_url    category_code  \
# ...

# %%
# Hago de nuevo la query, quedándome con lo que me interesa.

mydataset = db.companies.find({"$and": 
                               [{"offices.latitude": {"$exists": True}}, {"offices.latitude": {"$ne": None}},
                                {"offices.longitude": {"$exists": True}}, {"offices.longitude": {"$ne": None}},
                                {"category_code": {"$exists": True}}, {"category_code": {"$ne": None}},
                                {"name": {"$exists": True}}, {"name": {"$ne": None}},
                                {"founded_year": {"$gte": 2008}},
                                {"deadpooled_year": None},
                                {"number_of_employees": {"$ne": None}},
                                {"category_code": {"$ne": ["other", "semiconductor", "finance", "medical", "health",
                                                          "manufacturing", "real_estate", "fashion", "nanotech",
                                                          "hospitality", "transportation", "local"]}}]}, 
                              {"_id":1, "category_code":1,"founded_year":1, "name":1, 
                               "number_of_employees":1, "offices.country_code":1, "offices.latitude":1, 
                               "offices.longitude":1, "total_money_raised":1})

# %%
# dataframe = pd.DataFrame(list(mydataset))

# dataframe.head()

# %%
# Normalizo la columna offices, para separar los subvalores en columnas.

mydataframe = json_normalize(data = mydataset, record_path = "offices", 
                             meta = ["_id", "category_code", "founded_year", "name",
                                    "number_of_employees", "total_money_raised"])

# %%
mydataframe.head(10)
# Out:
#   country_code   latitude   longitude                       _id  \
# 0          USA  37.782263 -122.392142  52cdef7c4bab8bd675297e30
# 1          USA  42.358920  -71.057810  52cdef7c4bab8bd675297ee1
# 2          USA  47.597965 -122.151158  52cdef7c4bab8bd675297f3f
# 3          USA  37.781265 -122.393229  52cdef7c4bab8bd675297f76
# 4          USA  40.757929  -73.985506  52cdef7c4bab8bd675297f94
# 5          USA  33.817100 -111.903500  52cdef7c4bab8bd675297f9e
# 6          USA  37.566879 -122.323895  52cdef7c4bab8bd675297fec
# 7          DEU  53.707739   10.023246  52cdef7c4bab8bd675298038
# 8          USA  37.798853 -122.398599  52cdef7c4bab8bd6752981d8
# 9          CZE  49.225902   16.569282  52cdef7c4bab8bd6752981e8
#
#      category_code  founded_year         name  number_of_employees  \
# 0         software          2008      GoingOn                   40
# 1       enterprise          2008     Cloudant                   70
# ...

# %%
# Creo una columna que una las coordenadas, porque creo que la necesitaré para indexarla después en compass.

coordinates = []

for i in range(len(mydataframe["latitude"])):
    coordinates.append([mydataframe["latitude"][i], mydataframe["longitude"][i]])
        
mydataframe["coordinates"] = coordinates
mydataframe.head()
# Out:
#   country_code   latitude   longitude                       _id category_code  \
# 0          USA  37.782263 -122.392142  52cdef7c4bab8bd675297e30      software
# 1          USA  42.358920  -71.057810  52cdef7c4bab8bd675297ee1    enterprise
# 2          USA  47.597965 -122.151158  52cdef7c4bab8bd675297f3f   games_video
# 3          USA  37.781265 -122.393229  52cdef7c4bab8bd675297f76   games_video
# 4          USA  40.757929  -73.985506  52cdef7c4bab8bd675297f94        search
#
#    founded_year         name  number_of_employees total_money_raised  \
# 0          2008      GoingOn                   40              $8.5M
# 1          2008     Cloudant                   70             $18.3M
# 2          2008      YouBeQB                    8                 $0
# 3          2008  Crunchyroll                   50              $4.8M
# 4          2012      PeekYou                   20             $1.83M
#
#                 coordinates
# 0  [37.782263, -122.392142]
# ...

# %%
# Reordeno mis columnas para una mejor visualización.

columns = ["_id", "name", "category_code", "country_code", "founded_year", "number_of_employees", 
                         "total_money_raised", "coordinates", "latitude", "longitude"]

mydataframe = mydataframe.reindex_axis(["_id", "name", "category_code", "country_code", "founded_year", 
                                        "number_of_employees", "total_money_raised", "coordinates", "latitude", 
                                        "longitude"], axis= 1)

mydataframe.head()
# Out:
# /usr/local/Cellar/ipython/7.4.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#                         _id         name category_code country_code  \
# 0  52cdef7c4bab8bd675297e30      GoingOn      software          USA
# 1  52cdef7c4bab8bd675297ee1     Cloudant    enterprise          USA
# 2  52cdef7c4bab8bd675297f3f      YouBeQB   games_video          USA
# 3  52cdef7c4bab8bd675297f76  Crunchyroll   games_video          USA
# 4  52cdef7c4bab8bd675297f94      PeekYou        search          USA
#
#    founded_year  number_of_employees total_money_raised  \
# 0          2008                   40              $8.5M
# 1          2008                   70             $18.3M
# 2          2008                    8                 $0
# 3          2008                   50              $4.8M
# 4          2012                   20             $1.83M
#
# ...

# %% [markdown]
# Ahora tengo que normalizar los valores de las columnas que estén en formato json dentro de un array.

# %%
def prepareForTableau(mydataset):
    locations = json_normalize(bks["address"])
    gelocs = locations.apply(lambda e: [e["coord"][0],e["coord"][1]], result_type="expand", axis=1)
    clean_df = pd.concat([bks["restaurant_id"],locations[["street","zipcode"]],gelocs], axis=1)
    clean_df.rename({1:"lat",0:"long"}, axis=1, inplace=True)
    return clean_df

# %%
mydataset.to_json(orient= "records")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-63-2f75ca292cde> in <module>
# ----> 1 mydataset2.to_json(orient= 'records')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2271                             default_handler=default_handler,
#    2272                             lines=lines, compression=compression,
# -> 2273                             index=index)
#    2274
#    2275     def to_hdf(self, path_or_buf, key, **kwargs):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/json/json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
# ...
