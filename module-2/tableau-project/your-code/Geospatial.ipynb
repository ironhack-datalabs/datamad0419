# %%
from pymongo import MongoClient
import pandas as pd
import folium

client = MongoClient ('localhost', 27017)
db = client['companies']

# %%
a = db.companies_clean.find({'type_company':'Startup'})
for _ in a:
    print("La compañía {} que se dedica a {}, tiene {} empleados.".format(_['name'], _['category'], _['number_employees']))
# Out:
# La compañía Navara que se dedica a software, tiene 80 empleados.
# La compañía Wahanda que se dedica a web, tiene 50 empleados.
# La compañía Testplant que se dedica a software, tiene 50 empleados.
# La compañía Visuamobile que se dedica a software, tiene 35 empleados.
# La compañía Teambox que se dedica a web, tiene 35 empleados.
# La compañía EventElephant que se dedica a software, tiene 20 empleados.
# La compañía Planzone que se dedica a software, tiene 17 empleados.
# La compañía Worky que se dedica a web, tiene 16 empleados.
# La compañía Jibes que se dedica a web, tiene 15 empleados.
# La compañía Neovada que se dedica a web, tiene 16 empleados.
# La compañía Zankyou que se dedica a web, tiene 15 empleados.
# La compañía Zankyou que se dedica a web, tiene 15 empleados.
# La compañía Enternships que se dedica a web, tiene 15 empleados.
# La compañía Stupeflix que se dedica a web, tiene 15 empleados.
# La compañía TheWebService que se dedica a web, tiene 12 empleados.
# ...
