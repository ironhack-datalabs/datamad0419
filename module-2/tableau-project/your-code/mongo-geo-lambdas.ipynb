# %%
import pandas as pd
from pymongo import MongoClient
from pandas.io.json import json_normalize

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.companies
collection = db.companies

# %%
# FILTER {$and: [ {deadpooled_year:null}, {founded_year: {$gt:2003}}, {offices: { $ne: [] } }, {$or: [{category_code:'games_video'},{category_code:'software'}] }]}
# PROJECT {name:1 , category_code:1, number_of_employees:1, founded_year:1, "offices.city":1, "offices.country_code":1, "offices.latitude":1, "offices.longitude":1}
# SORT {number_of_employees:-1}

# %%
def query_to_db():
    cursor = collection.find({'$and': 
                        [ {'deadpooled_year':None}, 
                          {'founded_year': {'$gt':2003}},
                          {'offices': { '$ne': [] } },
                          {'$or': [{'category_code':'games_video'},
                                   {'category_code':'software'}] 
                        }]}
                        , {'name':1 , 'category_code':1, 'number_of_employees':1, 'founded_year':1, 
                           "offices.city":1, "offices.country_code":1, "offices.latitude":1, "offices.longitude":1}
                        ).sort('number_of_employees', -1)
    return pd.DataFrame(cursor)

# %%
def get_columns(data):
    data['country']= data['offices'].apply(lambda elem : elem[0]['country_code'])
    data['city']= data['offices'].apply(lambda elem : elem[0]['city'])
    data['lat']= data['offices'].apply(lambda elem : elem[0]['latitude'])
    data['long']= data['offices'].apply(lambda elem : elem[0]['longitude'])
    return data

# %%
def clean_cols_nans(data):
    data= data.drop(['_id', 'offices'], axis=1)
    data= data.dropna(subset=['lat', 'long'])
    return data

# %%
def calculate_type(reg):
    if reg['founded_year'] > 2007 and reg['number_of_employees'] < 50:
        return 'Startup'
    else: return 'BigCompany'
    
def get_class(data):
    data['type']= data.apply(calculate_type, axis=1)
    return data

# %%
# Main
df= query_to_db()
df_selected= get_columns(df)
df_clean= clean_cols_nans(df_selected)
df_final= get_class(df_clean)

# %%
df_final[500:550]
# Out:
#     category_code  founded_year                            name  \
# 715      software          2012                        Carfeine
# 716      software          2007                 Syntac Ventures
# 718      software          2007                          ORELIA
# 719      software          2005           Blue Sky Technologies
# 720      software          2008                    Uprizer Labs
# 721      software          2006                TimeLapse mobile
# 722      software          2007                        ipsojobs
# 723      software          2008                       TweetDeck
# 724   games_video          2007                         FABINET
# 725      software          2005                 Instil Software
# 726      software          2006                     Intelliverb
# 727      software          2007           Bridgevest eSolutions
# 728      software          2007                           Tingz
# 729   games_video          2008                           Bojam
# 730   games_video          2005                Project Amarillo
# 731      software          2008                      UpdateStar
# 732      software          2007           Bridgevest eSolutions
# 733      software          2007                           Tingz
# 734   games_video          2008                           Bojam
# 735   games_video          2005                Project Amarillo
# 736      software          2008                      UpdateStar
# 737      software          2007                VistaDB Software
# 738   games_video          2008                           TWIOA
# 739   games_video          2006                     Musicreview
# 740      software          2007                        Gigantiq
# 741      software          2008                           Buzzr
# 742      software          2008                   StellarSurvey
# 744      software          2008                      Rubysophic
# 745      software          2007             MindSpring Software
# 746   games_video          2008                     ZOOZ Mobile
# 748   games_video          2007                       Pilotlite
# 749   games_video          2006                            Away
# 751      software          2007                        ShedWorx
# 752   games_video          2007                          VIDDIX
# 753      software          2005                       speroware
# 755      software          2007                     Clikthrough
# 756   games_video          2005                    MyOtherDrive
# 757   games_video          2004                   RealityWanted
# 758      software          2007                           Calyx
# 759   games_video          2008                    CareerPlayer
# 760      software          2008                            iugo
# 761   games_video          2008                  Kramaley Games
# 763   games_video          2007  Entropy Computational Services
# 764      software          2008                         sexietv
# 766   games_video          2008                            Sabi
# 767   games_video          2007                    SocialRoster
# 769      software          2006                          Kalexo
# 770   games_video          2007                       UQ Events
# 771      software          2008        Sentry Parental Controls
# 772      software          2007                  Elca Solutions
#
#      number_of_employees country             city        lat        long  \
# 715                  5.0     USA         Bethesda  38.989124  -77.026676
# 716                  5.0     AUS        Melbourne -37.813339  144.970823
# 718                  5.0     FRA    Fontainebleau  48.407483    2.701038
# 719                  5.0     USA          Coppell  32.984488  -96.993293
# 720                  5.0     USA           Austin  30.291391  -97.710481
# 721                  5.0     USA           Novato  38.068295 -122.532658
# 722                  5.0     ESP        Barcelona  41.406248    2.163194
# 723                  5.0     GBR           London  51.500152   -0.126236
# 724                  5.0     DEU          Leipzig  51.318503   12.381492
# 725                  5.0     GBR          Belfast  54.597233   -5.879080
# 726                  5.0     USA           Laurel  39.143942  -76.877448
# 727                  5.0     NLD        Rotterdam  51.916547    4.475797
# 728                  5.0     USA        Knoxville  35.963029  -83.918392
# 729                  5.0     USA        Palo Alto  37.448598 -122.158497
# 730                  5.0     USA         Amarillo  33.515968 -101.905099
# 731                  5.0     DEU           Berlin  52.583651   13.285504
# 732                  5.0     NLD        Rotterdam  51.916547    4.475797
# 733                  5.0     USA        Knoxville  35.963029  -83.918392
# 734                  5.0     USA        Palo Alto  37.448598 -122.158497
# 735                  5.0     USA         Amarillo  33.515968 -101.905099
# 736                  5.0     DEU           Berlin  52.583651   13.285504
# 737                  5.0     USA       Mount Dora  28.841030  -81.685333
# 738                  5.0     USA           Toledo  41.652920  -83.577782
# 739                  5.0     IRL           dublin  53.335773   -6.371726
# 740                  5.0     AUS        Melbourne -37.813339  144.970823
# 741                  5.0     USA         New York  40.740941  -73.992609
# 742                  5.0     USA        Milwaukee  43.097697  -87.895093
# 744                  5.0     USA           Moraga  37.860866 -122.129671
# 745                  5.0     USA    Overland Park  38.929216  -94.685670
# 746                  5.0     USA          Atlanta  33.961646  -84.368975
# 748                  5.0     USA         New York  40.716682  -74.005398
# 749                  5.0     GRC           Athens  37.981544   23.756990
# 751                  5.0     AUS     Nedlands, WA -31.973020  115.813457
# 752                  5.0     NLD          Utrecht  52.084853    5.168245
# 753                  5.0     IND        Bangalore  12.928983   77.565254
# 755                  5.0     USA    San Francisco  37.796578 -122.402286
# 756                  5.0     USA           Dayton  39.760542  -84.194946
# 757                  5.0     USA  Manhattan Beach  33.889965 -118.396254
# 758                  5.0     HRV           Zagreb  45.802893   15.971618
# 759                  5.0     GBR           London  51.500152   -0.126236
# 760                  5.0     USA         Wheeling  40.067666  -80.723738
# 761                  5.0     GBR           London  51.494500   -0.147932
# 763                  5.0     ESP           Madrid  40.438087   -3.676064
# 764                  5.0     GBR           london  51.421362   -0.207594
# 766                  5.0     USA         Kirkland  47.666734 -122.195869
# 767                  5.0     USA        Baltimore  39.294989  -76.609500
# 769                  5.0     USA       Burlingame  37.589692 -122.340723
# 770                  5.0     CAN  North Vancouver  49.348403 -123.077897
# 771                  5.0     GBR       Manchester  53.519547   -2.255085
# 772                  5.0     USA      Gainesville  29.666674  -82.337553
#
#            type
# 715     Startup
# 716  BigCompany
# 718  BigCompany
# 719  BigCompany
# 720     Startup
# 721  BigCompany
# 722  BigCompany
# 723     Startup
# 724  BigCompany
# 725  BigCompany
# 726  BigCompany
# 727  BigCompany
# 728  BigCompany
# 729     Startup
# 730  BigCompany
# 731     Startup
# 732  BigCompany
# 733  BigCompany
# 734     Startup
# 735  BigCompany
# 736     Startup
# 737  BigCompany
# 738     Startup
# 739  BigCompany
# 740  BigCompany
# 741     Startup
# 742     Startup
# 744     Startup
# 745  BigCompany
# 746     Startup
# 748  BigCompany
# 749  BigCompany
# 751  BigCompany
# 752  BigCompany
# 753  BigCompany
# 755  BigCompany
# 756  BigCompany
# 757  BigCompany
# 758  BigCompany
# 759     Startup
# 760     Startup
# 761     Startup
# 763  BigCompany
# 764     Startup
# 766     Startup
# 767  BigCompany
# 769  BigCompany
# 770  BigCompany
# 771     Startup
# 772  BigCompany

# %%
df_final.to_json('data_to_plot_mongo.json', orient='records')
