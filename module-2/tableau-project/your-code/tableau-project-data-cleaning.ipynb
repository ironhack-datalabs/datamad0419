# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
df = pd.read_csv('tableau_project.csv', encoding = 'utf-8')
df = df.applymap(lambda x: x.strip() if type(x) is str else x)
df = df.drop(['Unnamed: 0'], axis = 1)
#Se eliminan también las columnas price_distance y price_duration por no encontrarse relación con price, duration y distance.
df = df.drop(['price_distance', 'price_duration'], axis = 1)
#Quitamos los espacios de principio y fin de los campos de texto
df = df.applymap(lambda x: x.strip() if type(x) is str else x)

# %%
pd.set_option('display.max_columns', 500) 
df.head(50)
df['journey_id'] = df.index
df.head(50)
# Out:
#     journey_id                   vehicle_type_id start_type  \
# 0            0  077866c3fd1a75f51ca7f8eae166ae32       asap
# 1            1  077866c3fd1a75f51ca7f8eae166ae32       asap
# 2            2  077866c3fd1a75f51ca7f8eae166ae32       asap
# 3            3  077866c3fd1a75f51ca7f8eae166ae32       asap
# 4            4  077866c3fd1a75f51ca7f8eae166ae32       asap
# 5            5  077866c3fd1a75f51ca7f8eae166ae32       asap
# 6            6  077866c3fd1a75f51ca7f8eae166ae32       asap
# 7            7  077866c3fd1a75f51ca7f8eae166ae32       asap
# 8            8  077866c3fd1a75f51ca7f8eae166ae32       asap
# 9            9  077866c3fd1a75f51ca7f8eae166ae32   reserved
# 10          10  077866c3fd1a75f51ca7f8eae166ae32       asap
# 11          11  077866c3fd1a75f51ca7f8eae166ae32       asap
# 12          12  077866c3fd1a75f51ca7f8eae166ae32       asap
# 13          13  077866c3fd1a75f51ca7f8eae166ae32       asap
# 14          14  077866c3fd1a75f51ca7f8eae166ae32       asap
# ...

# %%
df.isnull().sum()
# Out:
# journey_id                0
# vehicle_type_id           0
# start_type                0
# start_at                  0
# start_lat                 0
# start_lon                 0
# end_at                    0
# end_lat                  57
# end_lon                  57
# end_state                 0
# price                    20
# distance                 20
# duration                 20
# source                    0
# rider_waiting_time     1131
# driver_waiting_time    1179
# price_supplements         0
# discount                 20
# rating                    0
# dtype: int64

# %%
df.shape
# Out:
# (3864, 19)

# %%
null_cols = df.isnull().sum()
display(null_cols)
null_cols[null_cols > 0]
# Out:
# Unnamed: 0                0
# journey_id                0
# vehicle_type_id           0
# start_type                0
# start_at                  0
# start_lat                 0
# start_lon                 0
# end_at                    0
# end_lat                  57
# end_lon                  57
# end_state                 0
# price                    20
# price_distance         1052
# price_duration         1052
# distance                 20
# duration                 20
# source                    0
# rider_waiting_time     1131
# driver_waiting_time    1179
# price_supplements         0
# discount                 20
# rating                    0
# dtype: int64
# end_lat                  57
# end_lon                  57
# price                    20
# price_distance         1052
# price_duration         1052
# distance                 20
# duration                 20
# rider_waiting_time     1131
# driver_waiting_time    1179
# discount                 20
# dtype: int64
