# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pdpf

# %%
data = pd.read_csv("tableau_project.csv")
data.head(1000)
# Out:
#      Unnamed: 0                        journey_id  \
# 0             0  93e6d216088af74c32183283d4bb2953
# 1             1  444b084ec64244919afadfba879876a3
# 2             2  dbcc57f4e7606a71c74c6e4666a977a4
# 3             3  1ffe9a24033847148c683574985df56c
# 4             4  fb1ef7d070724482a33be41f27737ea5
# 5             5  310f2f7103dd41c9811bffa771776648
# 6             6  0a5bb1448fa2418581b7171df9f6d1a4
# 7             7  643a2da9e5f9457ab4a1706875c92d10
# 8             8  38aa6d5e20294992a6c31827d3a5a5c7
# 9             9  bd801b036699c6fdfdc530a6334ae88f
# 10           10  d61f40bbe1f942a8b9acab3a3f3d74f3
# 11           11  3fbde2354fd74135a87ce20b14af9a25
# 12           12  616bacc8c3d59829127c22f8eeb2ad34
# 13           13  0cdf9c4e11e5ed944879473e036ddc02
# 14           14  e0cd89ab902bcc6e6ba14de7606ee2d8
# 15           15  6dc46eede5d54730bdb0a9919ec0a2f1
# 16           16  65fa0803b8da46e8afc7a88909b3eaca
# 17           17  6694715bbad44cd1acf8a0eb665bef6f
# ...

# %%
data.shape
# Out:
# (3864, 22)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'journey_id', 'vehicle_type_id', 'start_type', 'start_at',
#        'start_lat', 'start_lon', 'end_at', 'end_lat', 'end_lon', 'end_state',
#        'price', 'price_distance', 'price_duration', 'distance', 'duration',
#        'source', 'rider_waiting_time', 'driver_waiting_time',
#        'price_supplements', 'discount', 'rating'],
#       dtype='object')

# %%
null_cols = data.isnull().sum()
print(null_cols[null_cols > 0])
# Out:
# end_lat                  57
# end_lon                  57
# price                    20
# price_distance         1052
# price_duration         1052
# distance                 20
# duration                 20
# rider_waiting_time     1131
# driver_waiting_time    1179
# discount                 20
# dtype: int64

# %%
data['end_state'].unique()
# Out:
# array(['drop off', 'rider cancel', 'no show', 'not found',
#        'driver cancel'], dtype=object)
