# %%
from pymongo import MongoClient
import pandas as pd
import json
from pandas.io.json import json_normalize
import re
from pymongo import MongoClient, GEO2D

# %%
client = MongoClient ('localhost', 27017)
db = client['companies']

# %%
# Ordena los datos según el año de fundación en orden descendente. El año más alto es 2013.
# db.companies.find_one(sort=[('founded_year', -1)])

# %%
# PRIMER PASO: FILTRO DE DATOS:
filtered = list(db.companies.find({'$and':[{'number_of_employees':{'$gte': 250}}, {'founded_year': {'$gte': 2009}}, {'offices.latitude': {'$exists': True}}, {'offices.longitude': {'$exists':True}}]}, ['offices.latitude', 'offices.longitude']))
filtered[:5]
# Out:
# [{'_id': ObjectId('52cdef7c4bab8bd675298608'),
#   'offices': [{'latitude': 34.052187, 'longitude': -118.243425}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529b2f3'),
#   'offices': [{'latitude': None, 'longitude': None}]},
#  {'_id': ObjectId('52cdef7e4bab8bd67529ba36'),
#   'offices': [{'latitude': None, 'longitude': None},
#    {'latitude': None, 'longitude': None},
#    {'latitude': None, 'longitude': None}]}]

# %%
# NÚMERO DE REGISTROS TRAS EL PRIMER FILTRO: 
db.companies.count_documents({'$and':[{'number_of_employees':{'$gte': 1}}, {'founded_year': {'$gte': 2009}}]})
# Out:
# 630

# %%
query_data = db.companies.find({'$and':[{'number_of_employees':{'$gt': 1}}, {'founded_year': {'$gt': 2009}}, {'offices.latitude': {'$exists': True}}, {'offices.longitude': {'$exists':True}}]})

# %%
df = json_normalize(data=query_data, record_path='offices', meta=['name', 'category_code', 'number_of_employees', 'founded_year', 'total_money_raised'])

# %%
df.head()
# Out:
#               address1   address2           city country_code description  \
# 0                                  San Francisco          USA
# 1                 None       None       New York          USA        None
# 2  4966 El Camino Real  Suite 200      Los Altos          USA
# 3     Ritterstr. 12-14                    Berlin          DEU
# 4       Fischerstr. 13                  Hannover          DEU
#
#     latitude   longitude state_code zip_code      name  founded_year  \
# 0        NaN         NaN         CA           CircleUp          2011
# 1  40.757929  -73.985506         NY     None   PeekYou          2012
# 2  33.817100 -111.903500         CA    94022     GENWI          2010
# 3  52.501345   13.410907       None    10969     headr          2012
# 4        NaN         NaN       None    30167     headr          2012
#
#   category_code total_money_raised  number_of_employees
# 0       finance                $9M                   11
# 1        search             $1.83M                   20
# 2        mobile              $7.1M                   25
# 3           web                 $0                    8
# 4           web                 $0                    8

# %%
# Borra filas con valores nulos en las columnas latitude, longitude, city and country_code
df = df.dropna(axis = 0, how ='any', subset=['latitude', 'longitude', 'city', 'country_code'])
df.head()
# Out:
#                     address1                 address2       city country_code  \
# 1                       None                     None   New York          USA
# 2        4966 El Camino Real                Suite 200  Los Altos          USA
# 3           Ritterstr. 12-14                              Berlin          DEU
# 5       One Franklin Parkway  Building 910, Suite 110  San Mateo          USA
# 6  460 Ste-Catherine W. #402                            Montreal          CAN
#
#   description   latitude   longitude state_code zip_code     name  \
# 1        None  40.757929  -73.985506         NY     None  PeekYou
# 2              33.817100 -111.903500         CA    94022    GENWI
# 3              52.501345   13.410907       None    10969    headr
# 5              37.566879 -122.323895         CA    94401    Fixya
# 6  Needium HQ  45.504931  -73.568163       None   H3B1A7  Needium
#
#    founded_year category_code total_money_raised  number_of_employees
# 1          2012        search             $1.83M                   20
# 2          2010        mobile              $7.1M                   25
# 3          2012           web                 $0                    8
# 5          2013           web                $8M                   30
# 6          2010    enterprise                $1M                   15

# %%
# Comprueba que latitud y longitud son de tipo float:
df.dtypes
# Out:
# address1                object
# address2                object
# city                    object
# country_code            object
# description             object
# latitude               float64
# longitude              float64
# state_code              object
# zip_code                object
# name                    object
# founded_year             int64
# category_code           object
# total_money_raised      object
# number_of_employees      int64
# dtype: object

# %%
# Una vez filtrados los datos y tras eliminar registros que tengan un valor nulo en las columnas 'latitude' o 'longitude'
# quedan estas empresas:
len(df)
# Out:
# 55

# %%
# Criterio empleado para clasificar las compañías como 'big': número de empleados igual o mayor a 250.
big1 = df[(df['number_of_employees'] >= 250)] 

# Según este criterio el porcentaje de big companies sobre el total de empresas, sería 0.021 
print('Big companies: {}'.format(len(big1)))
print('Total companies: {}'.format(len(df)))
print('Ratio Big companies / Total companies: {}'.format(len(big1)/len(df)))
# Out:
# Big companies: 1
# Total companies: 55
# Ratio Big companies / Total companies: 0.01818181818181818

# %%
#  Columna con formato adecuado para longitude y latitude. Ej: { type: "Point", coordinates: [ 40, 5 ] }
#  List the longitude first and then latitude

def get_geo(a, b):
    return {'type': 'Point', 'coordinates': [a, b]}

df['geopoint'] = df[['longitude', 'latitude']].apply(lambda x: get_geo(x['longitude'], x['latitude']), axis=1)

# %%
df.head(3)
# Out:
#               address1   address2       city country_code description  \
# 1                 None       None   New York          USA        None
# 2  4966 El Camino Real  Suite 200  Los Altos          USA
# 3     Ritterstr. 12-14                Berlin          DEU
#
#     latitude   longitude state_code zip_code     name  founded_year  \
# 1  40.757929  -73.985506         NY     None  PeekYou          2012
# 2  33.817100 -111.903500         CA    94022    GENWI          2010
# 3  52.501345   13.410907       None    10969    headr          2012
#
#   category_code total_money_raised  number_of_employees  \
# 1        search             $1.83M                   20
# 2        mobile              $7.1M                   25
# 3           web                 $0                    8
#
#                                             geopoint
# 1  {'coordinates': [-73.985506, 40.757929], 'type...
# 2  {'coordinates': [-111.9035, 33.8171], 'type': ...
# 3  {'coordinates': [13.4109071, 52.5013449], 'typ...

# %%
# Exporta el df a json:
df.to_json('./companies.json', orient='records', lines=True)

# %%
# Query sobre la colección 'geo' (la colección está en la base de datos 'companies')

# %%
def geoquery(lat, long, rad):
    client = MongoClient() 
    db = client['companies'] 
    
    geo = pd.DataFrame(db.geo.find({
        "geopoint": {
         "$near": {
           "$geometry": {
              "type": "Point" ,
              "coordinates": [long,lat]
           },
           "$maxDistance": rad, # In meters
         }
       }
    }))

    return geo

# %%
cities = pd.pivot_table(df, index=['country_code', 'city'], values=['number_of_employees'] , aggfunc=[len, sum])
cities
# Out:
#                                            len                 sum
#                            number_of_employees number_of_employees
# country_code city
# AUS          Queensland                      1                  10
# CAN          Kanata                          1                   3
#              Montreal                        1                  15
#              Toronto                         1                  60
#              Vancouver                       1                  10
# DEU          Berlin                          1                   8
# ESP          Bilbao                          1                   4
# GBR          Manchester                      1                  11
# IND          Bangalore                       1                  25
# NLD          Maarssen                        1                  80
# SGP          Singapore                       2                   8
# USA                                          1                   2
#              Bethesda                        1                   5
#              Beverly Hills                   1                 100
#              Burlington                      1                  30
#              Chicago                         2                  33
#              Denver                          2                  30
#              Fremont                         1                  25
#              Jacksonville                    1                  25
#              Los Altos                       1                  25
#              Los Angeles                     2                 375
#              Menlo Park                      1                   3
#              Miami                           1                   7
#              Mountain View                   1                  25
#              New York                        5                 193
#              North Haven                     1                   7
#              Palo Alto                       2                  15
#              Pompano Beach                   1                   3
#              Providence                      1                   5
#              San Francisco                   7                  99
#              San Mateo                       1                  30
#              Santa Clara                     1                   6
#              Santa Monica                    1                  18
#              Scottsdale                      2                 240
#              Seattle                         1                   4
#              Sunnyvale                       2                  14
#              Van Nuys                        2                   5

# %%
# Función para calcular el total de empleados en el área seleccionada
def get_employees_near(lat, lon, radio): 
    df = geoquery(lat, lon, radio)
    sum_empleados = df['number_of_employees'].sum()
    return sum_empleados

# %%
# Dataframe para el máximo número total de empleados tras filtrar las empresas que se dedican
# a los video juegos

empleados500 = []
radio = 500

for i in range(len(df)):
    lon, lat = df.iloc[i, 6], df.iloc[i, 5]  
    empleados500.append(get_employees_near(lat, lon, radio))
    
df['empleados500'] = empleados500

df = df[df['category_code']=='games_video'].sort_values(by=['empleados500'], ascending=False)
df.head(10)
# Out:
#                           address1          address2           city  \
# 72                                                    San Francisco
# 12     9570 W. Pico Blvd 3rd Floor                      Los Angeles
# 13       9606 S. Santa Monica Blvd         2nd Floor  Beverly Hills
# 71                                                        Bangalore
# 24                                                        Vancouver
# 70                                                          Fremont
# 23      1351 4th Street, 4th floor                     Santa Monica
# 66              1750 Montgomery St         Suite 150  San Francisco
# 86                Fortitude Valley  Fortitude Valley     Queensland
# 19  3979 Freedom Circle, Suite 610                      Santa Clara
#
#    country_code          description   latitude   longitude state_code  \
# 72          USA                       37.775196 -122.419204         CA
# 12          USA       HQ Los Angeles  37.446823 -122.161523         CA
# 13          USA                       34.069849 -118.405418         CA
# 71          IND         India Office  12.971606   77.594376       None
# 24          CAN            Vancouver  49.263588 -123.138565       None
# 70          USA            US Office  37.556171 -122.078063         CA
# 23          USA  Santa Monica Office  53.544711 -113.515769         CA
# 66          USA         Headquarters  37.805324 -122.405276         CA
# 86          AUS                      -27.457486  153.033686       None
# 19          USA                       37.760524 -122.387799         CA
#
#    zip_code                   name  founded_year category_code  \
# 72                          Fliggo          2012   games_video
# 12    90035  Social Gaming Network          2011   games_video
# 13    90210  Social Gaming Network          2011   games_video
# 71                     BASH Gaming          2010   games_video
# 24                      Pixelmatic          2011   games_video
# 70    94555            BASH Gaming          2010   games_video
# 23    90401           Titan Gaming          2010   games_video
# 66    94133                  Indee          2010   games_video
# 86     4006            ekidnaworld          2010   games_video
# 19    95054                   Fuzz          2011   games_video
#
#    total_money_raised  number_of_employees  \
# 72                 $0                    2
# 12             $17.1M                  100
# 13             $17.1M                  100
# 71                $1M                   25
# 24                 $0                   10
# 70                $1M                   25
# 23                $1M                   18
# 66                 $0                    3
# 86                 $0                   10
# 19                 $0                    6
#
#                                              geopoint  empleados500
# 72  {'coordinates': [-122.419204, 37.775196], 'typ...          1080
# 12  {'coordinates': [-122.161523, 37.446823], 'typ...           251
# 13  {'coordinates': [-118.4054182, 34.0698494], 't...           102
# 71  {'coordinates': [77.594376, 12.971606], 'type'...            67
# 24  {'coordinates': [-123.138565, 49.263588], 'typ...            27
# 70  {'coordinates': [-122.0780632, 37.5561712], 't...            25
# 23  {'coordinates': [-113.515769, 53.544711], 'typ...            18
# 66  {'coordinates': [-122.4052761, 37.8053241], 't...            17
# 86  {'coordinates': [153.033686, -27.4574861], 'ty...            10
# 19  {'coordinates': [-122.387799, 37.760524], 'typ...             6

# %%
df.head()
# Out:
#                        address1   address2           city country_code  \
# 72                                          San Francisco          USA
# 12  9570 W. Pico Blvd 3rd Floor               Los Angeles          USA
# 13    9606 S. Santa Monica Blvd  2nd Floor  Beverly Hills          USA
# 71                                              Bangalore          IND
# 24                                              Vancouver          CAN
#
#        description   latitude   longitude state_code zip_code  \
# 72                  37.775196 -122.419204         CA
# 12  HQ Los Angeles  37.446823 -122.161523         CA    90035
# 13                  34.069849 -118.405418         CA    90210
# 71    India Office  12.971606   77.594376       None
# 24       Vancouver  49.263588 -123.138565       None
#
#                      name  founded_year category_code total_money_raised  \
# 72                 Fliggo          2012   games_video                 $0
# 12  Social Gaming Network          2011   games_video             $17.1M
# 13  Social Gaming Network          2011   games_video             $17.1M
# 71            BASH Gaming          2010   games_video                $1M
# 24             Pixelmatic          2011   games_video                 $0
#
#     number_of_employees                                           geopoint  \
# 72                    2  {'coordinates': [-122.419204, 37.775196], 'typ...
# 12                  100  {'coordinates': [-122.161523, 37.446823], 'typ...
# 13                  100  {'coordinates': [-118.4054182, 34.0698494], 't...
# 71                   25  {'coordinates': [77.594376, 12.971606], 'type'...
# 24                   10  {'coordinates': [-123.138565, 49.263588], 'typ...
#
#     empleados500
# 72          1080
# 12           251
# 13           102
# 71            67
# 24            27

# %%
# pasas df a csv y lo representas
df.to_csv('top10companies.csv')
