# %%
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importamos el dataset
data = pd.read_csv('tableau_project.csv')

# %%
pd.set_option('display.max_columns', 500)

# %%
data.shape
# Out:
# (3864, 22)

# %%
data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 1           1  444b084ec64244919afadfba879876a3
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 3           3  1ffe9a24033847148c683574985df56c
# 4           4  fb1ef7d070724482a33be41f27737ea5
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 1  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:06:16
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 3  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 09:17:08
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
#
#    start_lat  start_lon               end_at    end_lat    end_lon  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260
# 1  19.431567 -99.195368  2017-12-16 11:07:21        NaN        NaN
# 2  19.422052 -99.174499  2017-11-24 23:27:05  19.438666 -99.180821
# 3  19.433119 -99.154844  2017-12-16 09:17:30  19.290148 -99.144407
# 4  19.440996 -99.183581  2017-11-24 18:31:31  19.422815 -99.174865
#
#       end_state  price price_distance price_duration distance duration  \
# 0      drop off  5,866          5,204              0    7,943    1,058
# 1  rider cancel      0              0              0        0        0
# 2      drop off  4,000          3,552              0    3,054      689
# 3  rider cancel      0              0              0        0        0
# 4      drop off  4,000          2,974             12    2,859      887
#
#     source rider_waiting_time driver_waiting_time price_supplements discount  \
# 0  Android                590                  48               662        0
# 1   iPhone                NaN                 NaN                 0        0
# 2  Android                923                   4                 0        0
# 3   iPhone                NaN                 NaN                 0        0
# 4   iPhone                329                  36                 0        0
#
#    rating
# 0     9.0
# 1     9.0
# 2    10.0
# 3     9.0
# 4     8.0

# %%
# pandas_profiling.ProfileReport(data)

# %%
# eliminar los viajes cancelados. nos quedamos solo con los viajes llevados a cabo
data = data[data['end_state'] == 'drop off']
data.shape
# Out:
# (2685, 22)

# %%
# contar nulls
null_cols = data.isnull().sum()
null_cols
# Out:
# Unnamed: 0              0
# journey_id              0
# vehicle_type_id         0
# start_type              0
# start_at                0
# start_lat               0
# start_lon               0
# end_at                  0
# end_lat                47
# end_lon                47
# end_state               0
# price                   0
# price_distance          0
# price_duration          0
# distance                0
# duration                0
# source                  0
# rider_waiting_time      0
# driver_waiting_time     0
# price_supplements       0
# discount                0
# rating                  0
# dtype: int64

# %%
# vamos a eliminar los registros que no tienen lugar de destino del viaje
data = data[pd.notnull(data['end_lat'])]
data.shape
# Out:
# (2638, 22)

# %%
null_cols = data.isnull().sum()
null_cols
# Out:
# Unnamed: 0             0
# journey_id             0
# vehicle_type_id        0
# start_type             0
# start_at               0
# start_lat              0
# start_lon              0
# end_at                 0
# end_lat                0
# end_lon                0
# end_state              0
# price                  0
# price_distance         0
# price_duration         0
# distance               0
# duration               0
# source                 0
# rider_waiting_time     0
# driver_waiting_time    0
# price_supplements      0
# discount               0
# rating                 0
# dtype: int64

# %%
# hay variables numéricas como categóricas
# los precios contienen comas en vez de puntos, por lo que hay que hacer replace
# no me cuadran en pesos ni en dólares. podría ser que estuvieran en céntimos de peso
def price_to_float(s):
    return float(s.replace(',', ''))/100

# parece que la distancia está en km, pero tiene una coma
# vamos a quitar la coma y a convertirlo en int
def distance_to_int(s):
    return float(s.replace(',', '.'))

# parece que la duración de los trayectos está en segundos, la vamos a pasar a minutos
def duration_to_min(s):
    return float(s.replace(',', ''))/60

# %%
# aplicamos la función para cambiar los precios
lst_price = ['price', 'price_distance', 'price_duration', 'price_supplements']
for column in lst_price:
    data[column] = data[column].map(price_to_float)

data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 4           4  fb1ef7d070724482a33be41f27737ea5
# 5           5  310f2f7103dd41c9811bffa771776648
# 7           7  643a2da9e5f9457ab4a1706875c92d10
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
# 5  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 15:34:53
# 7  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 15:09:29
#
#    start_lat  start_lon               end_at    end_lat    end_lon end_state  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260  drop off
# 2  19.422052 -99.174499  2017-11-24 23:27:05  19.438666 -99.180821  drop off
# 4  19.440996 -99.183581  2017-11-24 18:31:31  19.422815 -99.174865  drop off
# 5  19.421856 -99.174361  2017-11-24 15:53:30  19.440311 -99.184146  drop off
# 7  19.419962 -99.171955  2017-11-24 15:47:42  19.441434 -99.183503  drop off
#
#    price  price_distance  price_duration distance duration   source  \
# 0  58.66           52.04            0.00    7,943    1,058  Android
# 2  40.00           35.52            0.00    3,054      689  Android
# 4  40.00           29.74            0.12    2,859      887   iPhone
# 5  40.00           33.46            2.90    3,176    1,028   iPhone
# 7  64.49           43.67           20.82    3,008    1,505   iPhone
#
#   rider_waiting_time driver_waiting_time  price_supplements discount  rating
# 0                590                  48               6.62        0     9.0
# 2                923                   4               0.00        0    10.0
# 4                329                  36               0.00        0     8.0
# 5                 73                 369               0.00        0     8.0
# 7                770                 799               0.00        0    10.0

# %%
# vemos si hay registros con precio 0
noprice = data[data['price'] == 0]
print(len(noprice))
noprice.head()
# Out:
# 3
#       Unnamed: 0                        journey_id  \
# 919          919  8ad5e46e06566d8fc9ff06cf15be71f0
# 2809        2809  a73e8dc2a6264e80b95e3b709828623e
# 2972        2972  2d7b639b59b14565987ff1e83f6aaf2a
#
#                        vehicle_type_id start_type             start_at  \
# 919   21620ea5749f2e0679a8c72c7fbafb9e       asap  2017-06-07 12:58:33
# 2809  21620ea5749f2e0679a8c72c7fbafb9e       asap  2017-05-23 12:53:31
# 2972  21620ea5749f2e0679a8c72c7fbafb9e       asap  2017-04-21 18:03:56
#
#       start_lat  start_lon               end_at    end_lat    end_lon  \
# 919   19.438148 -99.181069  2017-06-07 13:05:32  19.422749 -99.174937
# 2809  19.356000 -99.275269  2017-05-23 13:50:20  19.441356 -99.183848
# 2972  19.425436 -99.178435  2017-04-21 18:16:44  19.415074 -99.170272
#
#      end_state  price  price_distance  price_duration distance duration  \
# 919   drop off    0.0            9.61            0.53    1,071      394
# 2809  drop off    0.0          110.87            0.00    9,483    2,149
# 2972  drop off    0.0            0.26            0.00      415      421
#
#        source rider_waiting_time driver_waiting_time  price_supplements  \
# 919   Android                 15                  51                0.0
# 2809   iPhone              1,235                   5                0.0
# 2972   iPhone                317                  21                0.0
#
#      discount  rating
# 919         0     9.0
# 2809        0     9.0
# 2972        0     9.0

# %%
# eliminamos las filas que tengan precio 0
data = data[data['price'] != 0]
data.shape
# Out:
# (2635, 22)

# %%
# aplicamos la función a la distancia
data['distance'] = data['distance'].map(distance_to_int)

# %%
# aplicamos la función para pasar los tiempos de segundos a minutos
lst_time = ['duration', 'rider_waiting_time', 'driver_waiting_time']
for column in lst_time:
    data[column] = data[column].map(duration_to_min)

# %%
# creamos columna con distance / price_distance
# creamos columna con duration / price_duration
data['price_per_km'] = data['price_distance'] / data['distance']
data['price_per_min'] = data['price_duration'] / data['duration']

# %%
data.head()
# Out:
#    Unnamed: 0                        journey_id  \
# 0           0  93e6d216088af74c32183283d4bb2953
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4
# 4           4  fb1ef7d070724482a33be41f27737ea5
# 5           5  310f2f7103dd41c9811bffa771776648
# 7           7  643a2da9e5f9457ab4a1706875c92d10
#
#                     vehicle_type_id start_type             start_at  \
# 0  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-12-16 11:08:59
# 2  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 22:58:37
# 4  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 18:11:00
# 5  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 15:34:53
# 7  077866c3fd1a75f51ca7f8eae166ae32       asap  2017-11-24 15:09:29
#
#    start_lat  start_lon               end_at    end_lat    end_lon end_state  \
# 0  19.431363 -99.195362  2017-12-16 11:37:32  19.406438 -99.175260  drop off
# 2  19.422052 -99.174499  2017-11-24 23:27:05  19.438666 -99.180821  drop off
# 4  19.440996 -99.183581  2017-11-24 18:31:31  19.422815 -99.174865  drop off
# 5  19.421856 -99.174361  2017-11-24 15:53:30  19.440311 -99.184146  drop off
# 7  19.419962 -99.171955  2017-11-24 15:47:42  19.441434 -99.183503  drop off
#
#    price  price_distance  price_duration  distance   duration   source  \
# 0  58.66           52.04            0.00     7.943  17.633333  Android
# 2  40.00           35.52            0.00     3.054  11.483333  Android
# 4  40.00           29.74            0.12     2.859  14.783333   iPhone
# 5  40.00           33.46            2.90     3.176  17.133333   iPhone
# 7  64.49           43.67           20.82     3.008  25.083333   iPhone
#
#    rider_waiting_time  driver_waiting_time  price_supplements discount  \
# 0            9.833333             0.800000               6.62        0
# 2           15.383333             0.066667               0.00        0
# 4            5.483333             0.600000               0.00        0
# 5            1.216667             6.150000               0.00        0
# 7           12.833333            13.316667               0.00        0
#
#    rating  price_per_km  price_per_min
# 0     9.0      6.551681       0.000000
# 2    10.0     11.630648       0.000000
# 4     8.0     10.402239       0.008117
# 5     8.0     10.535264       0.169261
# 7    10.0     14.517952       0.830033

# %%
# hay dos tipos de vehículos. vamos a ver si encontramos alguna relación con el precio
v_type = pd.pivot_table(data = data, values = ('price_per_km', 'price_per_min'), index = 'vehicle_type_id')
print(v_type)
# Out:
#                                   price_per_km  price_per_min
# vehicle_type_id
# 077866c3fd1a75f51ca7f8eae166ae32     11.487761       0.106010
# 21620ea5749f2e0679a8c72c7fbafb9e     11.382012       0.082633

# %%
# vemos que el precio por km es prácticamente igual en los dos tipos de vehículo
# sin embargo, en el precio por minuto sí que hay diferencia
# podríamos decir que puede que haya un vehículo con más plazas o de mayor categoría
# vamos a cambiar el id por car_a y car_b
def change_id(id):
    if id == '077866c3fd1a75f51ca7f8eae166ae32':
        return 'vehicle_a'
    elif id == '21620ea5749f2e0679a8c72c7fbafb9e':
        return 'vehicle_b'

# %%
data['vehicle_type_id'] = data['vehicle_type_id'].map(change_id)
data.head()
# Out:
#    Unnamed: 0                        journey_id vehicle_type_id start_type  \
# 0           0  93e6d216088af74c32183283d4bb2953       vehicle_a       asap
# 2           2  dbcc57f4e7606a71c74c6e4666a977a4       vehicle_a       asap
# 4           4  fb1ef7d070724482a33be41f27737ea5       vehicle_a       asap
# 5           5  310f2f7103dd41c9811bffa771776648       vehicle_a       asap
# 7           7  643a2da9e5f9457ab4a1706875c92d10       vehicle_a       asap
#
#               start_at  start_lat  start_lon               end_at    end_lat  \
# 0  2017-12-16 11:08:59  19.431363 -99.195362  2017-12-16 11:37:32  19.406438
# 2  2017-11-24 22:58:37  19.422052 -99.174499  2017-11-24 23:27:05  19.438666
# 4  2017-11-24 18:11:00  19.440996 -99.183581  2017-11-24 18:31:31  19.422815
# 5  2017-11-24 15:34:53  19.421856 -99.174361  2017-11-24 15:53:30  19.440311
# 7  2017-11-24 15:09:29  19.419962 -99.171955  2017-11-24 15:47:42  19.441434
#
#      end_lon end_state  price  price_distance  price_duration  distance  \
# 0 -99.175260  drop off  58.66           52.04            0.00     7.943
# 2 -99.180821  drop off  40.00           35.52            0.00     3.054
# 4 -99.174865  drop off  40.00           29.74            0.12     2.859
# 5 -99.184146  drop off  40.00           33.46            2.90     3.176
# 7 -99.183503  drop off  64.49           43.67           20.82     3.008
#
#     duration   source  rider_waiting_time  driver_waiting_time  \
# 0  17.633333  Android            9.833333             0.800000
# 2  11.483333  Android           15.383333             0.066667
# 4  14.783333   iPhone            5.483333             0.600000
# 5  17.133333   iPhone            1.216667             6.150000
# 7  25.083333   iPhone           12.833333            13.316667
#
#    price_supplements discount  rating  price_per_km  price_per_min
# 0               6.62        0     9.0      6.551681       0.000000
# 2               0.00        0    10.0     11.630648       0.000000
# 4               0.00        0     8.0     10.402239       0.008117
# 5               0.00        0     8.0     10.535264       0.169261
# 7               0.00        0    10.0     14.517952       0.830033

# %%
# vamos a eliminar las columnas que no nos hagan falta
data = data.drop(['Unnamed: 0', 'end_state'], axis=1)
data.head()
# Out:
#                          journey_id vehicle_type_id start_type  \
# 0  93e6d216088af74c32183283d4bb2953       vehicle_a       asap
# 2  dbcc57f4e7606a71c74c6e4666a977a4       vehicle_a       asap
# 4  fb1ef7d070724482a33be41f27737ea5       vehicle_a       asap
# 5  310f2f7103dd41c9811bffa771776648       vehicle_a       asap
# 7  643a2da9e5f9457ab4a1706875c92d10       vehicle_a       asap
#
#               start_at  start_lat  start_lon               end_at    end_lat  \
# 0  2017-12-16 11:08:59  19.431363 -99.195362  2017-12-16 11:37:32  19.406438
# 2  2017-11-24 22:58:37  19.422052 -99.174499  2017-11-24 23:27:05  19.438666
# 4  2017-11-24 18:11:00  19.440996 -99.183581  2017-11-24 18:31:31  19.422815
# 5  2017-11-24 15:34:53  19.421856 -99.174361  2017-11-24 15:53:30  19.440311
# 7  2017-11-24 15:09:29  19.419962 -99.171955  2017-11-24 15:47:42  19.441434
#
#      end_lon  price  price_distance  price_duration  distance   duration  \
# 0 -99.175260  58.66           52.04            0.00     7.943  17.633333
# 2 -99.180821  40.00           35.52            0.00     3.054  11.483333
# 4 -99.174865  40.00           29.74            0.12     2.859  14.783333
# 5 -99.184146  40.00           33.46            2.90     3.176  17.133333
# 7 -99.183503  64.49           43.67           20.82     3.008  25.083333
#
#     source  rider_waiting_time  driver_waiting_time  price_supplements  \
# 0  Android            9.833333             0.800000               6.62
# 2  Android           15.383333             0.066667               0.00
# 4   iPhone            5.483333             0.600000               0.00
# 5   iPhone            1.216667             6.150000               0.00
# 7   iPhone           12.833333            13.316667               0.00
#
#   discount  rating  price_per_km  price_per_min
# 0        0     9.0      6.551681       0.000000
# 2        0    10.0     11.630648       0.000000
# 4        0     8.0     10.402239       0.008117
# 5        0     8.0     10.535264       0.169261
# 7        0    10.0     14.517952       0.830033

# %%
f,ax = plt.subplots()
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
# el dataset ya está limpio. ahora vamos a guardarlo como csv para llevarlo a Tableau
data.to_csv('tableau-project-clean.csv')
