# %%
from pymongo import MongoClient
import json
from geojson import Polygon
import pandas as pd
import numpy as np

# %%
client = MongoClient()
db = client.companies
geo=db.geo.find({})
df=pd.DataFrame(geo)

# %% [markdown]
# A continuación se realiza una petición basada en la cercanía de los registros. Se obtiene el número de empresas que tiene cerca cada una de las empresas, la varianza en el número de empleados entre las empresas cercanas y la categorías de cada una de las empresas cercanas a una empresa. La varianza en el numero de empleados nos asegura que exista una mayor variedad de tamaños de empresas (startups vs grandes empresas). Las categorías se guardarán como una lista con la cual podremos comprobar si entre las empresas cercanas existen empresas de video_games.

# %%
def nearLoc(lon,lat):
    
    nearLocation = {"lng": lon, "lat": lat}

    x = pd.DataFrame(db.geo.find({
        "geo": {
         "$near": {
           "$geometry": {
              "type": "Point" ,
              "coordinates": [ nearLocation["lat"] , nearLocation["lng"]]
           },
           "$maxDistance": 10000, # In meters
         }
       }
    }))
    
    number_of_companies=x.shape[0]
    size_variance=x['number_of_employees'].std()
    categories=list(x['category_code'])
    
    return [number_of_companies,size_variance,categories]

res=list(map(nearLoc,df['latitude'], df['longitude']))

# %% [markdown]
# Se crean las nuevas columnas con la información sobre el número de empresas cercanas, la varianza en el número de empleados y la listas de categorías de las empresas cercanas.

# %%
df['near_companies']=list(i[0] for i in res)
df['size_variance']=list(i[1] for i in res)
df['categories']=list(i[2] for i in res)
df.head()
# Out:
#                         _id category_code           city  founded_year  \
# 0  5cd52f5440b61af8a9809714           web        Seattle          2005
# 1  5cd52f5440b61af8a9809715           web       New York          2005
# 2  5cd52f5440b61af8a9809716           web     Menlo Park          2003
# 3  5cd52f5440b61af8a9809717        mobile    Los Angeles          2005
# 4  5cd52f5440b61af8a9809718        social  New York City          2007
#
#                                                  geo   latitude   longitude  \
# 0  {'type': 'Point', 'coordinates': [-122.333253,...  47.603122 -122.333253
# 1  {'type': 'Point', 'coordinates': [-73.9964312,...  40.723731  -73.996431
# 2  {'type': 'Point', 'coordinates': [-122.169472,...  37.484130 -122.169472
# 3  {'type': 'Point', 'coordinates': [-118.446596,...  34.057498 -118.446596
# 4  {'type': 'Point', 'coordinates': [-73.985506, ...  40.757929  -73.985506
#
#        name  number_of_employees  near_companies  size_variance  \
# 0  Wetpaint                 47.0             113      45.232297
# 1  Wetpaint                 47.0             356    4591.503346
# 2    Gizmoz                  NaN             175     526.495217
# 3     Helio                  NaN              94      44.114945
# 4   MeetMoi                 15.0             352    4610.878102
#
#                                           categories
# 0  [web, software, software, network_hosting, web...
# 1  [web, other, enterprise, web, public_relations...
# 2  [web, games_video, enterprise, biotech, mobile...
# 3  [mobile, web, web, ecommerce, advertising, web...
# 4  [social, network_hosting, games_video, web, ne...

# %% [markdown]
# Se ordenan los registros según el número de empresas cercanas (y la varianza en el número de empleados como valor secundario) y se llama a esto model1.

# %%
model1=df.sort_values(by=['near_companies','size_variance'],ascending=False)
model1.head()
# Out:
#                            _id category_code           city  founded_year  \
# 1755  5cd52f5440b61af8a9809def   games_video  San Francisco          2008
# 1490  5cd52f5440b61af8a9809ce6           web  San Francisco          2002
# 1643  5cd52f5440b61af8a9809d7f           web  San Francisco          2002
# 15    5cd52f5440b61af8a9809723   games_video  San Francisco          2006
# 18    5cd52f5440b61af8a9809726           web  San Francisco          2005
#
#                                                     geo   latitude  \
# 1755  {'type': 'Point', 'coordinates': [-122.371203,...  37.804619
# 1490  {'type': 'Point', 'coordinates': [-122.3693356...  37.825523
# 1643  {'type': 'Point', 'coordinates': [-122.3693356...  37.825523
# 15    {'type': 'Point', 'coordinates': [-122.409173,...  37.788482
# 18    {'type': 'Point', 'coordinates': [-122.402567,...  37.793148
#
#        longitude         name  number_of_employees  near_companies  \
# 1755 -122.371203  Brightstorm                  NaN             393
# 1490 -122.369336  Blogcritics                  NaN             391
# 1643 -122.369336  Blogcritics                  NaN             391
# 15   -122.409173         Kyte                 40.0             387
# 18   -122.402567       Wesabe                  NaN             387
#
#       size_variance                                         categories
# 1755     111.391583  [games_video, network_hosting, hardware, web, ...
# 1490     110.793936  [web, web, games_video, web, cleantech, games_...
# 1643     110.793936  [web, web, games_video, web, cleantech, games_...
# 15       112.380609  [games_video, web, enterprise, web, enterprise...
# 18       112.380609  [web, search, enterprise, advertising, web, co...

# %% [markdown]
# Se ordenan los registros según la varianza en el número de empleados (y el número de empresas cercanas como valor secundario) y se llama a esto model2.

# %%
model2=df.sort_values(by=['size_variance','near_companies'],ascending=False)
model2.head()
# Out:
#                            _id category_code    city  founded_year  \
# 2496  5cd52f5440b61af8a980a0d4     ecommerce  Boston          2009
# 1745  5cd52f5440b61af8a9809de5        search  Boston          2005
# 681   5cd52f5440b61af8a98099bd           web  Boston          2008
# 704   5cd52f5440b61af8a98099d4           web  Boston          2007
# 91    5cd52f5440b61af8a980976f   advertising  Boston          2005
#
#                                                     geo   latitude  longitude  \
# 2496  {'type': 'Point', 'coordinates': [-71.0213788,...  42.398366 -71.021379
# 1745  {'type': 'Point', 'coordinates': [-71.127226, ...  42.415663 -71.127226
# 681   {'type': 'Point', 'coordinates': [-71.13129, 4...  42.322072 -71.131290
# 704   {'type': 'Point', 'coordinates': [-71.13129, 4...  42.322072 -71.131290
# 91    {'type': 'Point', 'coordinates': [-71.051931, ...  42.340889 -71.051931
#
#                         name  number_of_employees  near_companies  \
# 2496  Action Sports Branding                  3.0              88
# 1745         Brick Marketing                 10.0              91
# 681               InformedMD                  2.0              92
# 704                  TOKiBiz                  1.0              92
# 91                 ScanScout                 40.0              93
#
#       size_variance                                         categories
# 2496   14280.528585  [ecommerce, network_hosting, web, ecommerce, w...
# 1745   14137.059159  [search, web, enterprise, network_hosting, sea...
# 681    13997.794843  [web, web, mobile, ecommerce, mobile, biotech,...
# 704    13997.794843  [web, web, mobile, ecommerce, mobile, biotech,...
# 91     13862.640515  [advertising, advertising, software, ecommerce...

# %% [markdown]
# A continuación se cogerán los primeros 400 registros del modelo 1 y los primeros 400 registros del modelo 2 y se observará la intersección, es decir, aquellos valores que aparezcan como altos en cuanto al número de empresas cercanas y también en cuanto a la varianza en el número de empleados (que tengan variedad de empresas grandes y pequeñas). La empresas que aparezcan el la base llamada "best_choices" marcarán la localización (o localizaciones) ideal(es) para colocar nuestra empresa. Además, se observa si en estos puntos hay empresas de games_video cercanas, encontrándose que sí las hay para todas.

# %%
lst=[]
for i in list(model1['_id'][0:400]): 
    if i in list(model2['_id'][0:400]):
        lst.append(i)
best_choices=df.loc[(df['_id'].isin(lst))]

count=0
print(best_choices.shape[0])
for i in best_choices['categories']:
    if 'games_video' in i:
        print(count,'True')
    count+=1
# Out:
# 14
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# 10 True
# 11 True
# 12 True
# 13 True

# %%
best_choices
# Out:
#                            _id     category_code      city  founded_year  \
# 22    5cd52f5440b61af8a980972a       games_video  New York          2004
# 448   5cd52f5440b61af8a98098d4               web  New York          2006
# 568   5cd52f5440b61af8a980994c       games_video  New York          2001
# 602   5cd52f5440b61af8a980996e               web  New York          2007
# 942   5cd52f5440b61af8a9809ac2               web  New York          2005
# 1554  5cd52f5440b61af8a9809d26               web  New York          2008
# 1706  5cd52f5440b61af8a9809dbe               web  New York          2008
# 1749  5cd52f5440b61af8a9809de9  public_relations  New York          2007
# 1868  5cd52f5440b61af8a9809e60          software  New York          2006
# 2012  5cd52f5440b61af8a9809ef0       games_video  New York          2007
# 2334  5cd52f5440b61af8a980a032       advertising  New York          2001
# 2364  5cd52f5440b61af8a980a050         ecommerce  New York          2008
# 2494  5cd52f5440b61af8a980a0d2             other  New York          2006
# 2744  5cd52f5440b61af8a980a1cc        enterprise  New York          2006
#
#                                                     geo   latitude  longitude  \
# 22    {'type': 'Point', 'coordinates': [-73.99873, 4...  40.722655 -73.998730
# 448   {'type': 'Point', 'coordinates': [-74.005897, ...  40.715145 -74.005897
# 568   {'type': 'Point', 'coordinates': [-74.002662, ...  40.717248 -74.002662
# 602   {'type': 'Point', 'coordinates': [-74.00118, 4...  40.718871 -74.001180
# 942   {'type': 'Point', 'coordinates': [-74.0013669,...  40.723839 -74.001367
# 1554  {'type': 'Point', 'coordinates': [-74.004441, ...  40.721583 -74.004441
# 1706  {'type': 'Point', 'coordinates': [-74.004441, ...  40.721583 -74.004441
# 1749  {'type': 'Point', 'coordinates': [-73.9973, 40...  40.722118 -73.997300
# 1868  {'type': 'Point', 'coordinates': [-74.001169, ...  40.718888 -74.001169
# 2012  {'type': 'Point', 'coordinates': [-74.005398, ...  40.716682 -74.005398
# 2334  {'type': 'Point', 'coordinates': [-74.001487, ...  40.720331 -74.001487
# 2364  {'type': 'Point', 'coordinates': [-74.004602, ...  40.718177 -74.004602
# 2494  {'type': 'Point', 'coordinates': [-74.005897, ...  40.715145 -74.005897
# 2744  {'type': 'Point', 'coordinates': [-73.9986592,...  40.719628 -73.998659
#
#                            name  number_of_employees  near_companies  \
# 22               Pando Networks                 23.0             357
# 448                      Convos                  NaN             357
# 568                      Boonty                150.0             357
# 602                      Thrive                 15.0             357
# 942                      GoMobo                  NaN             357
# 1554                photothread                  NaN             357
# 1706                photothread                  NaN             357
# 1749                  GroundRez                 20.0             357
# 1868               ReverbNation                 85.0             357
# 2012                  Pilotlite                  5.0             357
# 2334  Saffron Brand Consultants                 80.0             357
# 2364              Digital Bloom                  5.0             357
# 2494                    Solidea                 50.0             357
# 2744                    Harvest                  NaN             357
#
#       size_variance                                         categories
# 22      4581.913489  [games_video, public_relations, other, web, mo...
# 448     4581.913489  [web, other, software, ecommerce, web, games_v...
# 568     4581.913489  [games_video, ecommerce, web, software, games_...
# 602     4581.913489  [web, software, advertising, games_video, ente...
# 942     4581.913489  [web, mobile, games_video, web, web, web, web,...
# 1554    4581.913489  [web, web, advertising, web, ecommerce, softwa...
# 1706    4581.913489  [web, web, advertising, web, ecommerce, softwa...
# 1749    4581.913489  [public_relations, games_video, other, web, en...
# 1868    4581.913489  [software, web, advertising, games_video, ente...
# 2012    4581.913489  [games_video, web, other, ecommerce, games_vid...
# 2334    4581.913489  [advertising, software, web, enterprise, web, ...
# 2364    4581.913489  [ecommerce, games_video, games_video, web, sof...
# 2494    4581.913489  [web, other, software, ecommerce, web, games_v...
# 2744    4581.913489  [enterprise, software, web, advertising, publi...

# %% [markdown]
# Se guarda best_choices para representar en tableau nuestro área de interés.

# %%
best_choices.to_csv('./best_choices.csv')

# %% [markdown]
# Para encontrar el punto central entre las 14 empresas obtenidas, habiendo visto en tableau que los puntos están muy próximos, se puede tratar la tierra como si fuese plana en este punto, y hallar el punto central de la siguiente manera:

# %%
ll=list(zip(best_choices['latitude'],best_choices['longitude']))


lat = []
long = []
for l in ll :
    lat.append(l[0])
    long.append(l[1])

final_lat=sum(lat)/len(lat)
final_long=sum(long)/len(long)
print('The best location to set my company is {}, {}'.format(final_lat, final_long))
# Out:
# The best location to set my company is 40.71942090714286, -74.00237357857142

# %% [markdown]
# La localización de las empresas pertenecientes a best_choices, las cuales determinan el punto central en el que se decidirá poner la empresa puede verse en tableau.
# URL: https://public.tableau.com/profile/patricia.rick#!/vizhome/Best_choices/Dashboard1?publish=yes
