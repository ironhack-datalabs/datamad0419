# %% [markdown]
# # Lab | Pandas Deep-Dive

# %% [markdown]
# ### 1. Import Pandas package under the alias pd and Numpy under the alias np

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Define a variable called `path` that contains the path to the csv file you downloaded.

# %%
path = 'data/apple_store.csv'

# %% [markdown]
# ### 3. Using the Pandas `read_csv()` method, import the csv file at the path above.
#
# Assign the returned value to a variable called `data`.
#
# Note: you can omit the `sep` parameter for `read_csv()` because the csv file uses the default separator of ",".

# %%
data = pd.read_csv(path)

# %% [markdown]
# ### 4. Print the first 5 rows of `data` to see what the data look like.
#
# A data analyst usually does this to have a general understanding about what the data look like before digging deep.

# %%
data.head(5)
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# 2       Weather
# 3      Shopping
# 4     Reference

# %% [markdown]
# ### 5. Print the summary (info) of the data.

# %%
data.describe()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver
# count       7197.000000  7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578
# std         3920.455183     1.517948         1.809363
# min            0.000000     0.000000         0.000000
# 25%            1.000000     3.500000         2.500000
# 50%           23.000000     4.000000         4.000000
# 75%          140.000000     4.500000         4.500000
# max       177050.000000     5.000000         5.000000

# %% [markdown]
# ### 6. Print the number of columns in the data.

# %%
len(data.columns)
# Out:
# 9

# %% [markdown]
# ### 7. Print all column names.

# %%
data.columns.to_list()
# Out:
# ['id',
#  'track_name',
#  'size_bytes',
#  'price',
#  'rating_count_tot',
#  'rating_count_ver',
#  'user_rating',
#  'user_rating_ver',
#  'prime_genre']

# %% [markdown]
# ## Now that we have a general understanding of the data, we'll start working on the challenge questions.
#
# ### 8. How many apps are there in the data source?
#
# Print the # of observations of the data.
#
# *Hint: Your code should return the number 7197.*

# %%
data['track_name'].value_counts().sum()
# Out:
# 7197

# %% [markdown]
# ### 9. What is the average rating of all apps?
#
# First, read the `user_rating` column into a varialbe named `user_rating`.

# %%
user_rating = data['user_rating']

# %% [markdown]
# Now you can calculate the average of the `user_rating` data.
#
# Your code should return 3.526955675976101

# %%
user_rating.mean()
# Out:
# 3.526955675976101

# %% [markdown]
# ### 10. How many apps have an average rating no less than 4?
#
# First, filter `user_rating` where its value >= 4.
#
# Assign the filtered dataframe to a new variable called `user_rating_high`.

# %%
user_rating_high= data.query('user_rating >= 4')
user_rating_high
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# 6      283646709             PayPal - Send and request money safely
# 7      284035177                            Pandora - Music & Radio
# 8      284666222                        PCalc - The Best Calculator
# 9      284736660                                        Ms. PAC-MAN
# 10     284791396                          Solitaire by MobilityWare
# 14     284862767                                           FreeCell
# 15     284876795             TripAdvisor Hotels Flights Restaurants
# 17     284910350     Yelp - Nearby Restaurants, Shopping & Services
# 18     284993459  Shazam - Discover music, artists, videos & lyrics
# 19     285005463                      Crash Bandicoot Nitro Kart 3D
# 20     285946052                                             iQuran
# 21     285994151                                        :) Sudoku +
# 22     286058814    Yahoo Sports - Teams, Scores, News & Highlights
# 23     286070473                          Mileage Log | Fahrtenbuch
# 24     286799607                        Cleartune - Chromatic Tuner
# 28     288120394                                           TouchOSC
# 29     288419283                                         RadarScope
# 31     289084315                              Period Tracker Deluxe
# 34     289894882                                        White Noise
# 35     290638154          iHeartRadio – Free Music & Radio Stations
# 37     290986013                      Deliveries: a package tracker
# 38     291430598                                      Hurricane Pro
# 39     292421271                                       Fieldrunners
# 40     292628469                                         Juxtaposer
# 43     293523031                                   Sonos Controller
# ...          ...                                                ...
# 7137  1179213211              VanDammemoji by Jean-Claude Van Damme
# 7138  1179267591  Multi Level Car Parking 6 Shopping Mall Garage...
# 7139  1179462965                                      Farming USA 2
# 7141  1179685798                   VR Video World - Virtual Reality
# 7147  1180340451                     Valley of Fear Virtual Reality
# 7148  1180467988   Christmas Swap 3 -Match toy & candy to countdown
# 7155  1181024195                           My Town : Beauty Contest
# 7158  1181358720              VPN Go - Safe Fast & Stable VPN Proxy
# 7159  1181526812                                      EMOJIZI BOOBA
# 7160  1181582218              Addon Creator Studio for Minecraft PE
# 7161  1181601206                                    Truth or Dare ·
# 7162  1181616006                                       Island Delta
# 7166  1181904201   4x4 Dirt Track Trials Forest Driving Parking Sim
# 7168  1182331762                      Escape from the frigid Igloo.
# 7170  1183234072                                          CTFxCmoji
# 7171  1183260922                    Room Escape Game - Santa's Room
# 7172  1183548754                               Rescue the Enchanter
# 7174  1183856228  VR Thrills: Roller Coaster 360 (Google Cardboard)
# 7175  1183986102   Santa Kids Hair Salon - Christmas Makeover Games
# 7177  1184800011                           Again - room escape game
# 7180  1185365336                   Laurie Hernandez the Human Emoji
# 7183  1185580782                                    Survivalcraft 2
# 7187  1186126548                          Escape Game: illumination
# 7188  1186384912       Demolition Derby Virtual Reality (VR) Racing
# 7191  1187282363                         Plead the Fifth - The Game
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      100788224   3.99             21292                26          4.0
# 1      158578688   0.00            161065                26          4.0
# 3      128512000   0.00            262241               649          4.0
# 4       92774400   0.00            985920              5320          4.5
# 5       10485713   0.99              8253              5516          4.0
# 6      227795968   0.00            119487               879          4.0
# 7      130242560   0.00           1126879              3594          4.0
# 8       49250304   9.99              1117                 4          4.5
# 9       70023168   3.99              7885                40          4.0
# 10      49618944   4.99             76720              4017          4.5
# 14      55153664   4.99              6340               668          4.5
# 15     207907840   0.00             56194                87          4.0
# 17     167407616   0.00            223885              3726          4.0
# 18     147093504   0.00            402925               136          4.0
# 19      10735026   2.99             31456              4178          4.0
# 20      70707916   1.99              2929               966          4.5
# 21       6169600   2.99             11447               781          5.0
# 22     130583552   0.00            137951               131          4.0
# 23      71203840   5.99                 8                 0          4.5
# 24      11423008   3.99              3241               297          4.0
# 28       4263936   4.99               782                 7          4.0
# 29     172772352   9.99              3449                23          4.0
# 31      40216576   1.99             13350               489          4.5
# 34      44129280   0.99             33426               299          4.0
# 35     116443136   0.00            293228               110          4.0
# 37      30016512   4.99              4684                10          4.0
# 38      29518848   2.99              2104                 0          4.5
# 39      66872320   2.99             41633                 6          4.0
# 40      45229056   2.99              3610                 7          4.5
# 43     107983872   0.00             48905              2691          4.5
# ...          ...    ...               ...               ...          ...
# 7137    17164288   0.99                18                 0          4.5
# 7138   219144192   0.00               162               162          4.0
# 7139   299749376   2.99               269                35          4.5
# 7141    97276928   0.00                88                26          4.5
# 7147   150863872   0.00                46                32          4.0
# 7148    62359552   0.00                96                96          4.5
# 7155   203589632   2.99                31                31          4.5
# 7158    55926784   0.00               881                 5          5.0
# 7159    52536320   1.99                 1                 1          4.0
# 7160    61915136   1.99               214               137          4.0
# 7161    31555584   0.00               109                32          4.5
# 7162   628180992   2.99                26                 0          4.5
# 7166   278811648   0.00              1441              1441          5.0
# 7168    89188352   0.00                 3                 3          4.0
# 7170    26077184   0.00                39                 4          5.0
# 7171   143346688   0.00                10                10          5.0
# 7172   242505728   3.99                55                29          4.5
# 7174   169535488   0.00                14                 4          4.0
# 7175    64244736   0.00                41                19          4.5
# 7177    33946624   0.00                11                 8          4.0
# 7180    94008320   0.00                26                 3          5.0
# 7183    57349120   3.99               292               292          4.0
# 7187    52342784   0.00                23                23          4.5
# 7188   168774656   0.00                18                18          4.0
# 7191    27853824   2.99                11                 0          4.0
# 7192   126644224   0.00               142                75          4.5
# 7193   120760320   0.00                30                30          4.5
# 7194   111322112   1.99                15                 0          4.5
# 7195    97235968   0.00                85                32          4.5
# 7196    90898432   0.00                 3                 3          5.0
#
#       user_rating_ver        prime_genre
# 0                 4.5              Games
# 1                 3.5       Productivity
# 3                 4.5           Shopping
# 4                 5.0          Reference
# 5                 4.0              Games
# 6                 4.5            Finance
# 7                 4.5              Music
# 8                 5.0          Utilities
# 9                 4.0              Games
# 10                4.5              Games
# 14                4.5              Games
# 15                3.5             Travel
# 17                4.5             Travel
# 18                4.5              Music
# 19                3.5              Games
# 20                4.5          Reference
# 21                5.0              Games
# 22                4.5             Sports
# 23                0.0           Business
# 24                4.0              Music
# 28                3.5              Music
# 29                4.5            Weather
# 31                5.0   Health & Fitness
# 34                5.0   Health & Fitness
# 35                3.0              Music
# 37                4.0          Utilities
# 38                0.0            Weather
# 39                3.0              Games
# 40                5.0      Photo & Video
# 43                4.5              Music
# ...               ...                ...
# 7137              0.0      Entertainment
# 7138              4.0              Games
# 7139              4.5              Games
# 7141              5.0      Photo & Video
# 7147              4.0              Games
# 7148              4.5              Games
# 7155              4.5              Games
# 7158              4.5           Business
# 7159              4.0          Utilities
# 7160              4.5      Entertainment
# 7161              4.5      Entertainment
# 7162              0.0              Games
# 7166              5.0              Games
# 7168              4.0              Games
# 7170              5.0  Social Networking
# 7171              5.0              Games
# 7172              4.5              Games
# 7174              3.5              Games
# 7175              4.5              Games
# 7177              4.0              Games
# 7180              5.0          Utilities
# 7183              4.0              Games
# 7187              4.5              Games
# 7188              4.0              Games
# 7191              0.0              Games
# 7192              4.5              Games
# 7193              4.5              Games
# 7194              0.0          Utilities
# 7195              4.5              Games
# 7196              5.0              Games
#
# [4781 rows x 9 columns]

# %% [markdown]
# Now obtain the length of `user_rating_high` which should return 4781.

# %%
len(user_rating_high)
# Out:
# 4781

# %% [markdown]
# ### 11. How many genres are there in total for all the apps?
#
# Define a new variable named `genres` that contains the `prime_genre` column of `data`. Google for how to obtain unique values of a dataframe column.

# %%
genres = set(data['prime_genre'])
genres
# Out:
# {'Book',
#  'Business',
#  'Catalogs',
#  'Education',
#  'Entertainment',
#  'Finance',
#  'Food & Drink',
#  'Games',
#  'Health & Fitness',
#  'Lifestyle',
#  'Medical',
#  'Music',
#  'Navigation',
#  'News',
#  'Photo & Video',
#  'Productivity',
#  'Reference',
#  'Shopping',
#  'Social Networking',
#  'Sports',
#  'Travel',
#  'Utilities',
#  'Weather'}

# %% [markdown]
# Print the length of the unique values of `genres`. Your code should return 23.

# %%
len(genres)
# Out:
# 23

# %% [markdown]
# ### 12. What are the top 3 genres that have the most number of apps?
#
# What you want to do is to count the number of occurrences of each unique genre values. Because you already know how to obtain the unique genre values, you can of course count the # of apps of each genre one by one. However, Pandas has a convient function to let you count all values of a dataframe column with a single command. Google for "pandas count values" to find the solution. Your code should return the following:
#
# ```
# Games            3862
# Entertainment     535
# Education         453
# Name: prime_genre, dtype: int64
# ```

# %%
data['prime_genre'].value_counts()[:3]
# Out:
# Games            3862
# Entertainment     535
# Education         453
# Name: prime_genre, dtype: int64

# %% [markdown]
# ### 13. Which genre is most likely to contain free apps?
#
# First, filter `data` where the price is 0.00. Assign the filtered data to a new variable called `free_apps`. Then count the values in `free_apps`. Your code should return:
#
# ```
# Games                2257
# Entertainment         334
# Photo & Video         167
# Social Networking     143
# Education             132
# Shopping              121
# Utilities             109
# Lifestyle              94
# Finance                84
# Sports                 79
# Health & Fitness       76
# Music                  67
# Book                   66
# Productivity           62
# News                   58
# Travel                 56
# Food & Drink           43
# Weather                31
# Navigation             20
# Reference              20
# Business               20
# Catalogs                9
# Medical                 8
# Name: prime_genre, dtype: int64
# ```

# %%
free_apps = data[data['price']==0]
free_apps_vc=free_apps['prime_genre'].value_counts()
free_apps_vc
# Out:
# Games                2257
# Entertainment         334
# Photo & Video         167
# Social Networking     143
# Education             132
# Shopping              121
# Utilities             109
# Lifestyle              94
# Finance                84
# Sports                 79
# Health & Fitness       76
# Music                  67
# Book                   66
# Productivity           62
# News                   58
# Travel                 56
# Food & Drink           43
# Weather                31
# Business               20
# Reference              20
# Navigation             20
# Catalogs                9
# Medical                 8
# Name: prime_genre, dtype: int64

# %% [markdown]
# ### 14. Now you can calculate the proportion of the free apps in each genre based on the value counts you obtained in the previous two steps.
#
# Challenge yourself by achieving that with one line of code. The output should look like:
#
# ```
# Shopping             0.991803
# Catalogs             0.900000
# Social Networking    0.856287
# Finance              0.807692
# News                 0.773333
# Sports               0.692982
# Travel               0.691358
# Food & Drink         0.682540
# Lifestyle            0.652778
# Entertainment        0.624299
# Book                 0.589286
# Games                0.584412
# Music                0.485507
# Photo & Video        0.478510
# Utilities            0.439516
# Navigation           0.434783
# Weather              0.430556
# Health & Fitness     0.422222
# Business             0.350877
# Productivity         0.348315
# Medical              0.347826
# Reference            0.312500
# Education            0.291391
# Name: prime_genre, dtype: float64
# ```
#
# The numbers are interesting, aren't they?

# %%
(free_apps_vc/data['prime_genre'].value_counts()).sort_values(ascending=False)
# Out:
# Shopping             0.991803
# Catalogs             0.900000
# Social Networking    0.856287
# Finance              0.807692
# News                 0.773333
# Sports               0.692982
# Travel               0.691358
# Food & Drink         0.682540
# Lifestyle            0.652778
# Entertainment        0.624299
# Book                 0.589286
# Games                0.584412
# Music                0.485507
# Photo & Video        0.478510
# Utilities            0.439516
# Navigation           0.434783
# Weather              0.430556
# Health & Fitness     0.422222
# Business             0.350877
# Productivity         0.348315
# Medical              0.347826
# Reference            0.312500
# Education            0.291391
# Name: prime_genre, dtype: float64

# %% [markdown]
# ### 15. If a developer tries to make money by developing and selling Apple Store apps, in which genre should s/he develop the apps? Please assume all apps cost the same amount of time and expense to develop.
#
# We will leave this question to you. There are several way to solve it. Ideally your output should look like below:
#
# ```
#     average_price              genre
# 21       8.776087            Medical
# 11       5.116316           Business
# 4        4.836875          Reference
# 6        4.835435              Music
# 1        4.330562       Productivity
# 15       4.124783         Navigation
# 16       4.028234          Education
# 12       1.916444   Health & Fitness
# 20       1.790536               Book
# 7        1.647621          Utilities
# 2        1.605417            Weather
# 18       1.552381       Food & Drink
# 14       1.473295      Photo & Video
# 0        1.432923              Games
# 8        1.120370             Travel
# 10       0.953070             Sports
# 13       0.889701      Entertainment
# 17       0.885417          Lifestyle
# 22       0.799000           Catalogs
# 19       0.517733               News
# 5        0.421154            Finance
# 9        0.339880  Social Networking
# 3        0.016311           Shopping
# ```

# %%
data['price'][data['prime_genre']=='Medical'].mean()
# Out:
# 8.77608695652174

# %%
profitable= data.groupby('prime_genre')['price'].mean()

# %%
profitable.sort_values(ascending=False)
# Out:
# prime_genre
# Medical              8.776087
# Business             5.116316
# Reference            4.836875
# Music                4.835435
# Productivity         4.330562
# Navigation           4.124783
# Education            4.028234
# Health & Fitness     1.916444
# Book                 1.790536
# Utilities            1.647621
# Weather              1.605417
# Food & Drink         1.552381
# Photo & Video        1.473295
# Games                1.432923
# Travel               1.120370
# Sports               0.953070
# Entertainment        0.889701
# Lifestyle            0.885417
# Catalogs             0.799000
# News                 0.517733
# Finance              0.421154
# Social Networking    0.339880
# Shopping             0.016311
# Name: price, dtype: float64
