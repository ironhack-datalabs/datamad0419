# %%
import pandas as pd
import numpy as np
import re

# %%
sharks_info = pd.read_csv('sharks.csv', encoding='ISO/8859/1')

# %%
sharks_info.head()
# Out:
#       Year Country     US zone            Area     Sex     Age Fatal Attack
# 0     2016     USA  East coast         Florida    Male      16           No
# 1     2016     USA  East coast         Florida    Male      36           No
# 2     2016     USA  East coast         Florida    Male      43           No
# 3     2016     USA  East coast         Florida    Male  Uknown           No
# 4     2016     USA  US Islands          Hawaii  Female      51           No
# 5     2016     USA  East coast  South Carolina  Female      12           No
# 6     2016     USA  East coast         Florida    Male       9           No
# 7     2016     USA  West coast      California    Male      22           No
# 8     2016     USA  East coast         Florida    Male      25           No
# 9     2016     USA  East coast         Florida    Male      37           No
# 10    2016     USA  East coast         Florida    Male      49           No
# ...
