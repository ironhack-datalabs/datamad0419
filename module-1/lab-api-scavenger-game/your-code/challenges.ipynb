# %% [markdown]
# # Challenge 1

# %%
import requests
import json

url = 'https://api.github.com/'

with open('../.txt') as k:
    key = k.read()
    
response = requests.get(url+'repos/ironhack-datalabs/datamad0419/forks')
res = response.json()
res
# Out:
# [{'id': 182284791,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxODIyODQ3OTE=',
#   'name': 'datamad0419',
#   'full_name': 'Rafel37/datamad0419',
#   'private': False,
#   'owner': {'login': 'Rafel37',
#    'id': 28777746,
#    'node_id': 'MDQ6VXNlcjI4Nzc3NzQ2',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/28777746?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rafel37',
#    'html_url': 'https://github.com/Rafel37',
#    'followers_url': 'https://api.github.com/users/Rafel37/followers',
#    'following_url': 'https://api.github.com/users/Rafel37/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Rafel37/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Rafel37/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Rafel37/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Rafel37/orgs',
#    'repos_url': 'https://api.github.com/users/Rafel37/repos',
# ...

# %%
lang = []

for i in range(len(res)):
    lang.append(res[i]['language'])

# %%
print(lang)
# Out:
# ['Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
set(lang)
# Out:
# {'Jupyter Notebook'}

# %% [markdown]
# # Challenge 2

# %%
response2 = requests.get(url+'repos/ironhack-datalabs/datamad0419/commits?since=2019-04-15T00:00:00Z')
res2 = response2.json()
res2
# Out:
# []

# %% [markdown]
# Dado que es el repositorio master, no hay ningún commit hecho a la rama master.
