# %% [markdown]
# # Lab | API Scavenger Game
#
# ## Goals Challenge 1: Fork Languages used among all the forks created from the main lab repo of Ironhack DA bootcamp
# * Obtain the full list of forks created from the main lab repo via Github API.
# * Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# * Hint: Each language should appear only once in your array.
# * Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
import requests
import json
import pandas as pd

# %%
url = "https://api.github.com/users/gabaxi/repos"

response = requests.get(url)
results = response.json()
results
# Out:
# [{'archive_url': 'https://api.github.com/repos/gabaxi/datamad0419/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/gabaxi/datamad0419/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/gabaxi/datamad0419/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/gabaxi/datamad0419/branches{/branch}',
#   'clone_url': 'https://github.com/gabaxi/datamad0419.git',
#   'collaborators_url': 'https://api.github.com/repos/gabaxi/datamad0419/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/gabaxi/datamad0419/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/gabaxi/datamad0419/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/gabaxi/datamad0419/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/gabaxi/datamad0419/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/gabaxi/datamad0419/contributors',
# ...

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/gabaxi/datamad041...     False
# 1  https://api.github.com/repos/gabaxi/git_rladie...     False
# 2  https://api.github.com/repos/gabaxi/lab-data-v...     False
# 3  https://api.github.com/repos/gabaxi/lab-resolv...     False
# 4  https://api.github.com/repos/gabaxi/m1-0419-py...     False
# 5  https://api.github.com/repos/gabaxi/my-first-b...     False
# 6  https://api.github.com/repos/gabaxi/my_first_b...     False
# 7  https://api.github.com/repos/gabaxi/oh-my-zsh/...     False
# 8  https://api.github.com/repos/gabaxi/prework-da...     False
# 9  https://api.github.com/repos/gabaxi/PyLadies/{...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/gabaxi/datamad041...
# 1  https://api.github.com/repos/gabaxi/git_rladie...
# 2  https://api.github.com/repos/gabaxi/lab-data-v...
# 3  https://api.github.com/repos/gabaxi/lab-resolv...
# ...

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datamad0419/forks"
response_forks = requests.get(url)
results_forks = response_forks.json()
results_forks
#print(m["starred_url"])
# Out:
# [{'archive_url': 'https://api.github.com/repos/Rafel37/datamad0419/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/Rafel37/datamad0419/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/Rafel37/datamad0419/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/Rafel37/datamad0419/branches{/branch}',
#   'clone_url': 'https://github.com/Rafel37/datamad0419.git',
#   'collaborators_url': 'https://api.github.com/repos/Rafel37/datamad0419/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/Rafel37/datamad0419/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/Rafel37/datamad0419/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/Rafel37/datamad0419/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/Rafel37/datamad0419/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/Rafel37/datamad0419/contributors',
# ...

# %%
data_forks = pd.DataFrame(results_forks)
data_forks.head(10)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/Rafel37/datamad04...     False
# 1  https://api.github.com/repos/maxsanchezdp/data...     False
# 2  https://api.github.com/repos/alonsopdani/datam...     False
# 3  https://api.github.com/repos/eduleste/datamad0...     False
# 4  https://api.github.com/repos/vicenteccastillo/...     False
# 5  https://api.github.com/repos/JacoboP/datamad04...     False
# 6  https://api.github.com/repos/PatriciaRick/data...     False
# 7  https://api.github.com/repos/albertogcmr/datam...     False
# 8  https://api.github.com/repos/serguma/datamad04...     False
# 9  https://api.github.com/repos/YonatanRA/datamad...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/Rafel37/datamad04...
# 1  https://api.github.com/repos/maxsanchezdp/data...
# 2  https://api.github.com/repos/alonsopdani/datam...
# 3  https://api.github.com/repos/eduleste/datamad0...
# ...

# %%
data_forks['language'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     Jupyter Notebook
# 1     Jupyter Notebook
# 2     Jupyter Notebook
# 3     Jupyter Notebook
# 4     Jupyter Notebook
# 5     Jupyter Notebook
# 6     Jupyter Notebook
# 7     Jupyter Notebook
# 8     Jupyter Notebook
# 9     Jupyter Notebook
# 10    Jupyter Notebook
# 11    Jupyter Notebook
# 12    Jupyter Notebook
# 13    Jupyter Notebook
# 14    Jupyter Notebook
# 15    Jupyter Notebook
# 16    Jupyter Notebook
# 17    Jupyter Notebook
# 18    Jupyter Notebook
# 19    Jupyter Notebook
# 20    Jupyter Notebook
# Name: language, dtype: object>

# %%
languages = []
for i in results_forks:
    languages.append(i['language'])
print(languages)
# Out:
# ['Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook', 'Jupyter Notebook']

# %%
print('programming languages are used among all the forks created from the main lab repo are:',set(languages))
# Out:
# programming languages are used among all the forks created from the main lab repo are: {'Jupyter Notebook'}

# %% [markdown]
# ## Goal Challenge 2: Count Commits
#
# * Count how many commits were made in the past week.
# * Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
# * Count how many commit objects are contained in the array.

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datamad0419/commits?since=2019-04-15T00:00:00Z&until=2019-04-21T00:00:00Z"
response_commits = requests.get(url)
results_commits = response_commits.json()
results_commits
# Out:
# []

# %%
# como no ha habido commit con el repo master, sale una lista vacia
# para chequear si pongo otro repo y amplio el plazo (donde sé que si he tenido) si que me salen los commits realizados
url = "https://api.github.com/repos/gabaxi/super-duper-robot/commits?since=2019-01-15T00:00:00Z&until=2019-04-21T00:00:00Z"
response_commits = requests.get(url)
results_commits = response_commits.json()
results_commits
# Out:
# [{'author': {'avatar_url': 'https://avatars0.githubusercontent.com/u/38539359?v=4',
#    'events_url': 'https://api.github.com/users/gabaxi/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/gabaxi/followers',
#    'following_url': 'https://api.github.com/users/gabaxi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gabaxi/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/gabaxi',
#    'id': 38539359,
#    'login': 'gabaxi',
#    'node_id': 'MDQ6VXNlcjM4NTM5MzU5',
#    'organizations_url': 'https://api.github.com/users/gabaxi/orgs',
#    'received_events_url': 'https://api.github.com/users/gabaxi/received_events',
#    'repos_url': 'https://api.github.com/users/gabaxi/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/gabaxi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gabaxi/subscriptions',
#    'type': 'User',
# ...

# %%
data_commits = pd.DataFrame(results_commits)
data_commits.head(10)
# Out:
#                                               author  \
# 0  {'login': 'gabaxi', 'id': 38539359, 'node_id':...
# 1  {'login': 'gabaxi', 'id': 38539359, 'node_id':...
# 2  {'login': 'gabaxi', 'id': 38539359, 'node_id':...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/gabaxi/super-dupe...
# 1  https://api.github.com/repos/gabaxi/super-dupe...
# 2  https://api.github.com/repos/gabaxi/super-dupe...
#
#                                               commit  \
# 0  {'author': {'name': '@Cecil_gabaxi', 'email': ...
# 1  {'author': {'name': '@Cecil_gabaxi', 'email': ...
# 2  {'author': {'name': '@Cecil_gabaxi', 'email': ...
#
#                                            committer  \
# 0  {'login': 'gabaxi', 'id': 38539359, 'node_id':...
# 1  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 2  {'login': 'web-flow', 'id': 19864447, 'node_id...
#
#                                             html_url  \
# ...

# %%
url = "https://api.github.com/repos/ironhack-datalabs/datamad0419/commits"
response_commits = requests.get(url)
results_commits = response_commits.json()
results_commits

GET /repos/:owner/:repo/git/commits/:commit_sha
# Out:
#   File "<ipython-input-12-965c787b21a4>", line 6
#     GET /repos/:owner/:repo/git/commits/:commit_sha
#                ^
# SyntaxError: invalid syntax

# %%
for i in results_commits:
    for i in results_commits['author']:
        commits_messages = []
        commits_messages.append(results_commits['author'][i])
print(commits_messages)

# %% [markdown]
# ## Goal Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
